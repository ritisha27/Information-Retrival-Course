# %% [markdown]
# # **Q3. Phrase Queries**

# %%
# importing the libraries
from nltk.corpus import stopwords
import collections
import itertools
import pickle
import pprint
import nltk
import os
import re

nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# extracting the zip folder of processed data from question 1
# !unzip '/content/processed_data_A1.zip'

# %% [markdown]
# # **(i) Bigram inverted index**

# %%
DATA_DIRECTORY = '/content/CSE508_Winter2023_Dataset'

# %%
# function to read a file.
def file_read(file_path):
  with open(file_path, "r") as file:
    data = file.read()
    
  return data

# %%
# checking the correctness of the function
file_read('/content/CSE508_Winter2023_Dataset/cranfield0001')
# Out:
# 'experimental investigation aerodynamics wing slipstream experimental study wing propeller slipstream made order determine spanwise distribution lift increase due slipstream different angles attack wing different free stream slipstream velocity ratios results intended part evaluation basis different theoretical treatments problem comparative span loading curves together supporting evidence showed substantial part lift increment produced slipstream due destalling boundarylayercontrol effect integrated remaining lift increment subtracting destalling lift found agree well potential flow theory empirical evaluation destalling effects made specific configuration experiment'

# %%
# making a dictionary that stores docID and its content.
indexed_file_content = dict()
files = sorted(os.listdir(DATA_DIRECTORY))

# enumerating over all the files in the given directory and store 
# the key as docID (index) and the value as the content of the file
for index, file in enumerate(files):
  file_path =  DATA_DIRECTORY + '/' + file
  data = file_read(file_path)
  indexed_file_content[index+1] = data

# %%
# splitting the content of the file, so to make tokens
for i in range(1, len(indexed_file_content)+1):
  indexed_file_content[i] = indexed_file_content[i].split()

# %%
bigram_inverted_index = dict()

# create bigram inverted index.
for i in range(1, len(indexed_file_content)+1):
  size = len(indexed_file_content[i])
  for j in range (0, size-1):
    bigram_tuple = (indexed_file_content[i][j], indexed_file_content[i][j+1])
    try:
      bigram_inverted_index[bigram_tuple].add(i)
    except:
      bigram_inverted_index[bigram_tuple] = set()
      bigram_inverted_index[bigram_tuple].add(i)


# now sort the posting lists for each biword 
temp = bigram_inverted_index.keys()
for i in temp:
  bigram_inverted_index[i] = sorted(bigram_inverted_index[i])

# %%
for key, value in bigram_inverted_index.items():
  print(key, ' : ', value)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('disturbances', 'flow')  :  [1313]
# ('nozzle', 'entry')  :  [1313]
# ('entry', 'caused')  :  [1313]
# ('caused', 'waves')  :  [1313]
# ('reflected', 'contact')  :  [1313]
# ('contact', 'surface')  :  [1313]
# ('surface', 'operating')  :  [1313]
# ('conditions', 'depart')  :  [1313]
# ('depart', 'first')  :  [1313]
# ('first', 'disturbance')  :  [1313]
# ('disturbance', 'reflected')  :  [1313]
# ('surface', 'weak')  :  [1313]
# ('weak', 'enough')  :  [1313]
# ('enough', 'tolerated')  :  [1313]
# ('tolerated', 'within')  :  [1313]
# ('small', 'range')  :  [1313]
# ('range', 'primaryshock')  :  [1313]
# ('primaryshock', 'mach')  :  [1313]
# ('number', 'eg')  :  [1313]
# ('eg', '5')  :  [1313]
# ('5', '7')  :  [1313]
# ('6', '3')  :  [1313]
# ('3', 'pressure')  :  [1313]
# ('pressure', 'entry')  :  [1313]
# ('entry', 'nozzle')  :  [1313]
# ('nozzle', 'remain')  :  [1313]
# ('constant', '10')  :  [1313]
# ('cent', 'within')  :  [1313]
# ('range', 'running')  :  [1313]
# ('times', 'much')  :  [1313]
# ('much', 'longer')  :  [1313]
# ('longer', 'obtained')  :  [1313]
# ('obtained', 'straightthrough')  :  [1313]
# ('straightthrough', 'shock')  :  [1313]
# ('tunnels', 'predicted')  :  [1313]
# ('predicted', 'limitation')  :  [1313]
# ('limitation', 'usually')  :  [1313]
# ('usually', 'imposed')  :  [1313]
# ('imposed', 'arrival')  :  [1313]
# ('arrival', 'expansion')  :  [1313]
# ('wave', 'originating')  :  [1313]
# ('originating', 'diaphragm')  :  [1313]
# ('diaphragm', 'outside')  :  [1313]
# ('number', 'uniformflow')  :  [1313]
# ('uniformflow', 'duration')  :  [1313]
# ('duration', 'arrival')  :  [1313]
# ('arrival', 'nozzle')  :  [1313]
# ('entry', 'primary')  :  [1313]
# ('primary', 'shock')  :  [1313]
# ('equal', 'time')  :  [1313]
# ('time', 'arrival')  :  [1313]
# ('arrival', 'primary')  :  [1313]
# ('shock', 'contact')  :  [1313]
# ('surface', 'straightthrough')  :  [1313]
# ('tunnel', 'first')  :  [1313]
# ('first', 'sight')  :  [1313]
# ('sight', 'appears')  :  [1313]
# ('appears', 'therefore')  :  [1313]
# ('therefore', 'advantages')  :  [1313]
# ('advantages', 'reflectedshock')  :  [1313]
# ('reflectedshock', 'operation')  :  [1313]
# ('operation', 'confined')  :  [1313]
# ('confined', 'narrow')  :  [1313]
# ('number', 'unless')  :  [1313]
# ('unless', 'heated')  :  [1313]
# ('heated', 'driver')  :  [1313]
# ('used', 'order')  :  [1313]
# ('order', 'vary')  :  [1313]
# ('analysis', 'suggests')  :  [1313]
# ('suggests', 'however')  :  [1313]
# ('subsequent', 'disturbances')  :  [1313]
# ('disturbances', 'multiple')  :  [1313]
# ('multiple', 'wave')  :  [1313]
# ('process', 'contact')  :  [1313]
# ('surface', 'end')  :  [1313]
# ('end', 'tube')  :  [1313]
# ('tube', 'relatively')  :  [1313]
# ('relatively', 'weak')  :  [1313]
# ('weak', 'useful')  :  [1313]
# ('useful', 'range')  :  [1313]
# ('number', 'thus')  :  [1313]
# ('thus', 'flow')  :  [1313]
# ('flow', 'arrival')  :  [1313]
# ('arrival', 'early')  :  [1313]
# ('early', 'reflected')  :  [1313]
# ('reflected', 'disturbances')  :  [1313]
# ('disturbances', 'used')  :  [1313]
# ('test', 'purposes')  :  [1313, 1353]
# ('purposes', 'long')  :  [1313]
# ('long', 'running')  :  [1313]
# ('times', 'seem')  :  [1313]
# ('seem', 'possible')  :  [1313]
# ('possible', 'theory')  :  [1313]
# ('without', 'severe')  :  [1313]
# ('severe', 'restrictions')  :  [1313]
# ('restrictions', 'shock')  :  [1313]
# ('number', 'experiments')  :  [1313]
# ('tube', 'shock')  :  [1313]
# ('tunnel', 'provide')  :  [1313]
# ('data', 'comparisons')  :  [1313]
# ('theory', 'allowance')  :  [1313]
# ('effects', 'motion')  :  [1313]
# ('motion', 'contact')  :  [1313]
# ('surface', 'fair')  :  [1313]
# ('found', 'disturbances')  :  [1313]
# ('disturbances', 'reflected')  :  [1313]
# ('reflected', 'transmitted')  :  [1313]
# ('transmitted', 'contact')  :  [1313]
# ('surface', 'arrival')  :  [1313]
# ('process', 'increases')  :  [1313]
# ('increases', 'shock')  :  [1313]
# ('number', 'raised')  :  [1313]
# ('raised', 'substantially')  :  [1313]
# ('substantially', 'tailored')  :  [1313]
# ('tailored', 'value')  :  [1313]
# ('value', 'limit')  :  [1313]
# ('limit', 'usable')  :  [1313]
# ('usable', 'flow')  :  [1313]
# ('duration', 'may')  :  [1313]
# ('result', 'striking')  :  [1313]
# ('striking', 'feature')  :  [1313]
# ('results', 'fall')  :  [1313]
# ('fall', 'pressure')  :  [1313]
# ('pressure', 'end')  :  [1313]
# ('tube', 'immediately')  :  [1313]
# ('immediately', 'reflection')  :  [1313]
# ('reflection', 'primary')  :  [1313]
# ('attributed', 'attenuation')  :  [1313]
# ('attenuation', 'reflected')  :  [1313]
# ('shock', 'resulting')  :  [1313]
# ('tube', 'research')  :  [1313]
# ('research', 'required')  :  [1313]
# ('check', 'explanation')  :  [1313]
# ('explanation', 'investigate')  :  [1313]
# ('number', 'crosssectional')  :  [1313]
# ('size', 'tube')  :  [1313]
# ('effects', 'tail')  :  [1313]
# ('tail', 'reflected')  :  [1313]
# ('reflected', 'head')  :  [1313]
# ('head', 'expansion')  :  [1313]
# ('originating', 'main')  :  [1313]
# ('main', 'diaphragm')  :  [1313]
# ('diaphragm', 'discussed')  :  [1313]
# ('shown', 'arrival')  :  [1313]
# ('arrival', 'reflected')  :  [1313]
# ('head', 'nozzle')  :  [1313]
# ('entry', 'may')  :  [1313]
# ('may', 'impose')  :  [1313]
# ('impose', 'severe')  :  [1313]
# ('severe', 'limitation')  :  [1313]
# ('limitation', 'duration')  :  [1313]
# ('duration', 'uniform')  :  [1313]
# ('uniform', 'conditions')  :  [1313]
# ('conditions', 'low')  :  [1313]
# ('low', 'shock')  :  [1313]
# ('number', 'arrival')  :  [1313]
# ('arrival', 'tail')  :  [1313]
# ('tail', 'may')  :  [1313]
# ('may', 'limit')  :  [1313]
# ('limit', 'flow')  :  [1313]
# ('duration', 'high')  :  [1313]
# ('high', 'shock')  :  [1313]
# ('unless', 'means')  :  [1313]
# ('means', 'devised')  :  [1313]
# ('devised', 'suppress')  :  [1313]
# ('suppress', 'expansion')  :  [1313]
# ('wave', 'demonstrated')  :  [1313]
# ('demonstrated', 'desirable')  :  [1313]
# ('desirable', 'alternative')  :  [1313]
# ('alternative', 'diaphragm')  :  [1313]
# ('diaphragm', 'positions')  :  [1313]
# ('positions', 'tube')  :  [1313]
# ('tube', 'required')  :  [1313]
# ('required', 'operate')  :  [1313]
# ('operate', 'range')  :  [1313]
# ('number', 'concluded')  :  [1313]
# ('concluded', 'running')  :  [1313]
# ('times', 'order')  :  [1313]
# ('10', 'milliseconds')  :  [1313]
# ('4', 'falling')  :  [1313]
# ('falling', 'perhaps')  :  [1313]
# ('perhaps', '1')  :  [1313]
# ('1', 'millisecond')  :  [1313]
# ('millisecond', 'shock')  :  [1313]
# ('8', 'seem')  :  [1313]
# ('tunnel', 'reasonable')  :  [1313]
# ('reasonable', 'size')  :  [1313]
# ('size', 'using')  :  [1313]
# ('using', 'reflectedshock')  :  [1313]
# ('operation', 'unheated')  :  [1313]
# ('unheated', 'hydrogen')  :  [1313]
# ('driving', 'air')  :  [1313]
# ('air', 'simplifying')  :  [1313]
# ('assumptions', 'theoretical')  :  [1313]
# ('investigations', 'deficiencies')  :  [1313]
# ('deficiencies', 'apparatus')  :  [1313]
# ('used', 'experiments')  :  [1313]
# ('investigation', 'must')  :  [1313]
# ('however', 'regarded')  :  [1313]
# ('regarded', 'preliminary')  :  [1313]
# ('preliminary', 'character')  :  [1313]
# ('character', 'research')  :  [1313]
# ('check', 'extend')  :  [1313]
# ('extend', 'findings')  :  [1313]
# ('findings', 'topics')  :  [1313]
# ('topics', 'particularly')  :  [1313]
# ('particularly', 'requiring')  :  [1313]
# ('requiring', 'investigation')  :  [1313]
# ('investigation', 'listed')  :  [1313]
# ('listed', 'paper')  :  [1313]
# ('production', 'high')  :  [1314]
# ('temperature', 'gases')  :  [1314]
# ('gases', 'shock')  :  [1314]
# ('tubes', 'paper')  :  [1314]
# ('paper', 'intended')  :  [1314]
# ('intended', 'set')  :  [1314]
# ('forth', 'aerodynamic')  :  [1314]
# ('aerodynamic', 'thermodynamic')  :  [1314]
# ('thermodynamic', 'calculations')  :  [1314]
# ('calculations', 'useful')  :  [1314]
# ('useful', 'production')  :  [1314]
# ('production', 'strong')  :  [1314]
# ('waves', 'experimental')  :  [1314]
# ('experimental', 'production')  :  [1314]
# ('waves', 'discussed')  :  [1314]
# ('discussed', 'comparison')  :  [1314, 1337]
# ('strengths', 'theoretical')  :  [1314]
# ('theoretical', 'calcualtions')  :  [1314]
# ('calcualtions', 'made')  :  [1314]
# ('made', 'finally')  :  [1314]
# ('finally', 'preliminary')  :  [1314]
# ('tube', 'studies')  :  [1314]
# ('studies', 'high')  :  [1314]
# ('gases', '18000k')  :  [1314]
# ('18000k', 'briefly')  :  [1314]
# ('briefly', 'surveyed')  :  [1314]
# ('estimates', 'rae')  :  [1315]
# ('rae', '6in')  :  [1315]
# ('6in', 'highpressure')  :  [1315]
# ('highpressure', 'shock')  :  [1315]
# ('tube', 'estimates')  :  [1315]
# ('made', 'performance')  :  [1315]
# ('performance', 'rae')  :  [1315]
# ('rae', '6')  :  [1315]
# ('6', 'high')  :  [1315]
# ('pressure', 'shock')  :  [1315]
# ('tube', 'various')  :  [1315]
# ('various', 'driver')  :  [1315]
# ('gases', 'range')  :  [1315]
# ('ratios', 'giving')  :  [1315]
# ('giving', 'shock')  :  [1315]
# ('6', '22')  :  [1315]
# ('22', 'calculations')  :  [1315]
# ('based', 'simplified')  :  [1315]
# ('model', 'shock')  :  [1315]
# ('fluid', 'argonfree')  :  [1315]
# ('argonfree', 'air')  :  [1315]
# ('assumed', 'always')  :  [1315]
# ('always', 'chemical')  :  [1315]
# ('equilibrium', 'driver')  :  [1315]
# ('either', 'hydrogen')  :  [1315]
# ('hydrogen', 'products')  :  [1315]
# ('products', 'combustion')  :  [1315]
# ('combustion', 'hydrogenoxygen')  :  [1315]
# ('hydrogenoxygen', 'mixture')  :  [1315]
# ('assumed', 'behave')  :  [1315]
# ('behave', 'ideal')  :  [1315]
# ('constant', 'specifiic')  :  [1315]
# ('specifiic', 'heats')  :  [1315]
# ('heats', 'results')  :  [1315]
# ('presented', 'graphical')  :  [1315]
# ('form', 'comprise')  :  [1315]
# ('comprise', 'charts')  :  [1315]
# ('charts', 'normal')  :  [1315]
# ('waves', 'argonfree')  :  [1315]
# ('wave', 'mach')  :  [1315]
# ('number', 'diaphragm')  :  [1315]
# ('diaphragm', 'pressure')  :  [1315]
# ('ratio', 'various')  :  [1315]
# ('conditions', 'shockinduced')  :  [1315]
# ('shockinduced', 'flows')  :  [1315]
# ('flows', 'uniformsectioned')  :  [1315]
# ('uniformsectioned', 'shock')  :  [1315]
# ('tube', 'expanded')  :  [1315]
# ('expanded', 'divergent')  :  [1315]
# ('divergent', 'nozzle')  :  [1315]
# ('measurements', 'shockwaves')  :  [1316]
# ('shockwaves', 'spectrumline')  :  [1316]
# ('spectrumline', 'reversal')  :  [1316]
# ('reversal', 'ii')  :  [1316]
# ('ii', 'double')  :  [1316]
# ('double', 'beam')  :  [1316]
# ('beam', 'method')  :  [1316]
# ('method', 'sodiumline')  :  [1316]
# ('sodiumline', 'reversal')  :  [1316, 1318]
# ('reversal', 'method')  :  [1316, 1318]
# ('using', 'photomultiplier')  :  [1316]
# ('photomultiplier', 'oscillograph')  :  [1316]
# ('oscillograph', 'modified')  :  [1316]
# ('modified', 'two')  :  [1316]
# ('two', 'light')  :  [1316]
# ('light', 'beams')  :  [1316]
# ('beams', 'employed')  :  [1316]
# ('employed', 'interference')  :  [1316]
# ('interference', 'filters')  :  [1316]
# ('filters', 'used')  :  [1316]
# ('used', 'front')  :  [1316]
# ('front', 'photomultipliers')  :  [1316]
# ('photomultipliers', 'instead')  :  [1316]
# ('instead', 'spectrograph')  :  [1316]
# ('spectrograph', 'one')  :  [1316]
# ('one', 'beam')  :  [1316]
# ('beam', 'background')  :  [1316]
# ('background', 'source')  :  [1316]
# ('source', 'viewed')  :  [1316]
# ('viewed', 'directly')  :  [1316]
# ('directly', 'shock')  :  [1316]
# ('tube', 'beam')  :  [1316]
# ('viewed', 'shock')  :  [1316]
# ('tube', 'mirror')  :  [1316]
# ('mirror', 'system')  :  [1316]
# ('system', 'neutral')  :  [1316]
# ('neutral', 'filter')  :  [1316]
# ('filter', 'interposed')  :  [1316]
# ('interposed', 'reduce')  :  [1316]
# ('reduce', 'effective')  :  [1316]
# ('effective', 'brightness')  :  [1316]
# ('brightness', 'temperature')  :  [1316]
# ('temperature', 'suitably')  :  [1316]
# ('chosen', 'temperature')  :  [1316]
# ('temperature', 'background')  :  [1316]
# ('background', 'one')  :  [1316]
# ('one', 'oscillograph')  :  [1316]
# ('oscillograph', 'trace')  :  [1316]
# ('trace', 'indicates')  :  [1316]
# ('indicates', 'absorption')  :  [1316]
# ('absorption', 'indicates')  :  [1316]
# ('indicates', 'emission')  :  [1316]
# ('emission', 'sodium')  :  [1316]
# ('sodium', 'lines')  :  [1316]
# ('lines', 'thus')  :  [1316]
# ('possible', 'records')  :  [1316]
# ('records', 'single')  :  [1316]
# ('single', 'shock')  :  [1316, 1356]
# ('shock', 'determine')  :  [1316]
# ('history', 'behind')  :  [1316]
# ('wave', '20degreec')  :  [1316]
# ('20degreec', 'nitrogen')  :  [1316]
# ('oxygen', 'show')  :  [1316]
# ('show', 'relaxation')  :  [1316]
# ('effects', 'near')  :  [1316]
# ('near', 'front')  :  [1316]
# ('front', 'temperatures')  :  [1316]
# ('temperatures', 'argon')  :  [1316]
# ('argon', 'tend')  :  [1316]
# ('tend', 'come')  :  [1316]
# ('come', 'low')  :  [1316]
# ('low', 'owing')  :  [1316]
# ('owing', 'radiative')  :  [1316]
# ('radiative', 'disequilibrium')  :  [1316]
# ('disequilibrium', 'excitation')  :  [1316]
# ('excitation', 'processes')  :  [1316]
# ('processes', 'argon')  :  [1316]
# ('argon', 'discussed')  :  [1316]
# ('discussed', 'system')  :  [1316]
# ('system', 'possible')  :  [1316]
# ('determine', 'temperatures')  :  [1316]
# ('temperatures', 'rather')  :  [1316]
# ('rather', 'higher')  :  [1316]
# ('higher', 'background')  :  [1316]
# ('source', 'work')  :  [1316]
# ('also', 'done')  :  [1316]
# ('done', 'singlebeam')  :  [1316]
# ('singlebeam', 'method')  :  [1316]
# ('using', 'carbon')  :  [1316]
# ('carbon', 'arc')  :  [1316]
# ('arc', 'background')  :  [1316]
# ('background', 'following')  :  [1316]
# ('following', 'reversal')  :  [1316]
# ('reversal', 'indium')  :  [1316]
# ('indium', 'blue')  :  [1316]
# ('blue', 'line')  :  [1316]
# ('line', 'temperatures')  :  [1316]
# ('temperatures', '3600degreek')  :  [1316]
# ('3600degreek', 'measured')  :  [1316]
# ('measured', 'shocks')  :  [1316]
# ('shocks', 'nitrogen')  :  [1316]
# ('nitrogen', 'time')  :  [1316]
# ('time', 'resolution')  :  [1316]
# ('resolution', 'good')  :  [1316]
# ('shocktube', 'testing')  :  [1317]
# ('time', 'theoretical')  :  [1317]
# ('attenuation', 'effects')  :  [1317]
# ('wave', 'conservation')  :  [1317]
# ('mass', 'equation')  :  [1317]
# ('equation', 'led')  :  [1317]
# ('led', 'explanation')  :  [1317]
# ('explanation', 'difference')  :  [1317]
# ('difference', 'ideal')  :  [1317]
# ('ideal', 'theoretical')  :  [1317]
# ('test', 'time')  :  [1317]
# ('time', 'experimentally')  :  [1317]
# ('time', 'numerical')  :  [1317]
# ('tunnel', 'using')  :  [1318]
# ('using', 'sodiumline')  :  [1318]
# ('method', 'sodium')  :  [1318]
# ('sodium', 'line')  :  [1318]
# ('line', 'reversal')  :  [1318]
# ('reversal', 'slr')  :  [1318]
# ('slr', 'method')  :  [1318]
# ('method', 'recently')  :  [1318]
# ('recently', 'used')  :  [1318]
# ('measure', 'transient')  :  [1318]
# ('temperatures', '1400degreek')  :  [1318]
# ('1400degreek', '3000degreek')  :  [1318]
# ('3000degreek', 'range')  :  [1318]
# ('range', 'example')  :  [1318]
# ('example', 'ref6')  :  [1318]
# ('ref6', 'reports')  :  [1318]
# ('reports', 'measurements')  :  [1318]
# ('measurements', 'gun')  :  [1318]
# ('gun', 'flash')  :  [1318]
# ('flash', 'temperatures')  :  [1318]
# ('temperatures', 'gun')  :  [1318]
# ('temperatures', 'range')  :  [1318]
# ('range', 'generated')  :  [1318]
# ('body', 'bow')  :  [1318]
# ('wave', 'gas')  :  [1318]
# ('temperature', 'zone')  :  [1318]
# ('zone', 'close')  :  [1318]
# ('stagnation', 'value')  :  [1318]
# ('ftsec', 'shock')  :  [1319]
# ('conditions', 'order')  :  [1319]
# ('wave', 'shapes')  :  [1319]
# ('temperatures', 'owing')  :  [1319]
# ('owing', 'real')  :  [1319]
# ('wave', 'detachment')  :  [1319]
# ('effects', 'experimentally')  :  [1319]
# ('plate', 'correlated')  :  [1319]
# ('correlated', 'analytical')  :  [1319]
# ('divergence', 'plate')  :  [1320]
# ('plate', 'airfoils')  :  [1320]
# ('airfoils', 'low')  :  [1320]
# ('ratio', 'supersonic')  :  [1320]
# ('speeds', 'part')  :  [1320]
# ('1', 'first')  :  [1320]
# ('first', 'approach')  :  [1320]
# ('approach', 'theoretical')  :  [1320]
# ('investigation', 'low')  :  [1320]
# ('plate', 'wings')  :  [1320]
# ('wings', 'constant')  :  [1320]
# ('thickness', 'two')  :  [1320]
# ('two', 'assumptions')  :  [1320]
# ('made', 'spanwise')  :  [1320]
# ('spanwise', 'form')  :  [1320]
# ('form', 'structural')  :  [1320]
# ('structural', 'distortion')  :  [1320]
# ('distortion', 'known')  :  [1320]
# ('known', 'leaving')  :  [1320]
# ('leaving', 'chordwise')  :  [1320]
# ('chordwise', 'distortion')  :  [1320]
# ('distortion', 'arbitrary')  :  [1320]
# ('arbitrary', 'b')  :  [1320]
# ('b', 'aerodynamic')  :  [1320]
# ('approximations', 'supersonic')  :  [1320]
# ('supersonic', 'linearized')  :  [1320]
# ('theory', 'form')  :  [1320]
# ('form', 'chordwise')  :  [1320]
# ('distortion', 'deduced')  :  [1320]
# ('deduced', 'differential')  :  [1320]
# ('equation', 'representing')  :  [1320]
# ('representing', 'state')  :  [1320]
# ('state', 'neutral')  :  [1320]
# ('equilibrium', 'small')  :  [1320]
# ('displacements', 'critical')  :  [1320]
# ('critical', 'divergence')  :  [1320]
# ('divergence', 'speed')  :  [1320]
# ('speed', 'secondly')  :  [1320]
# ('secondly', 'problem')  :  [1320]
# ('using', 'measured')  :  [1320]
# ('measured', 'structural')  :  [1320]
# ('structural', 'flexibility')  :  [1320]
# ('flexibility', 'coefficients')  :  [1320]
# ('coefficients', 'together')  :  [1320]
# ('together', 'theoretical')  :  [1320]
# ('coefficients', 'thirdly')  :  [1320]
# ('thirdly', 'usual')  :  [1320]
# ('based', 'rayleighritz')  :  [1320]
# ('rayleighritz', 'approach')  :  [1320]
# ('approach', 'discussed')  :  [1320]
# ('discussed', 'using')  :  [1320]
# ('using', 'assumptions')  :  [1320]
# ('assumptions', 'first')  :  [1320]
# ('methods', 'consistent')  :  [1320]
# ('consistent', 'indicate')  :  [1320]
# ('indicate', 'transonic')  :  [1320]
# ('transonic', 'regime')  :  [1320]
# ('regime', '1')  :  [1320]
# ('1', 'critical')  :  [1320]
# ('divergence', 'part')  :  [1320]
# ('2', 'established')  :  [1320]
# ('established', 'sweeping')  :  [1320]
# ('sweeping', 'leading')  :  [1320]
# ('plate', 'airfoil')  :  [1320]
# ('airfoil', 'constant')  :  [1320]
# ('thickness', 'increases')  :  [1320]
# ('increases', 'stability')  :  [1320]
# ('stability', 'angles')  :  [1320]
# ('angles', 'sweep')  :  [1320]
# ('sweep', 'less')  :  [1320]
# ('less', '30')  :  [1320]
# ('30', 'critical')  :  [1320]
# ('critical', 'conditions')  :  [1320]
# ('occur', 'leading')  :  [1320]
# ('sonic', 'angles')  :  [1320]
# ('greater', '30')  :  [1320]
# ('occur', '1')  :  [1320]
# ('effects', 'flexible')  :  [1321]
# ('flexible', 'boundary')  :  [1321]
# ('boundary', 'hydrodynamic')  :  [1321]
# ('hydrodynamic', 'stability')  :  [1321]
# ('stability', 'purpose')  :  [1321]
# ('paper', 'examine')  :  [1321]
# ('examine', 'theoretically')  :  [1321]
# ('theoretically', 'use')  :  [1321]
# ('use', 'coatings')  :  [1321]
# ('coatings', 'elastic')  :  [1321]
# ('elastic', 'materials')  :  [1321]
# ('materials', 'prevent')  :  [1321]
# ('prevent', 'transition')  :  [1321]
# ('extension', 'flexible')  :  [1321]
# ('boundary', 'smalldisturbance')  :  [1321]
# ('smalldisturbance', 'tollmienschlichting')  :  [1321]
# ('tollmienschlichting', 'stability')  :  [1321]
# ('theory', 'makes')  :  [1321]
# ('use', 'tietjens')  :  [1321]
# ('tietjens', 'function')  :  [1321]
# ('functions', 'occur')  :  [1321]
# ('solution', 'orrsommerfeld')  :  [1321]
# ('orrsommerfeld', 'equation')  :  [1321]
# ('solutions', 'flexible')  :  [1321]
# ('flexible', 'wall')  :  [1321]
# ('wall', 'obtained')  :  [1321]
# ('obtained', 'solutions')  :  [1321, 1394]
# ('solutions', 'rigid')  :  [1321]
# ('rigid', 'boundary')  :  [1321]
# ('boundary', 'outline')  :  [1321]
# ('outline', 'discussion')  :  [1321]
# ('first', 'tollmienschlichting')  :  [1321]
# ('theory', 'rigid')  :  [1321]
# ('rigid', 'wall')  :  [1321]
# ('theory', 'flexible')  :  [1321]
# ('boundary', 'theory')  :  [1321]
# ('given', 'nondissipative')  :  [1321]
# ('nondissipative', 'dissipative')  :  [1321]
# ('dissipative', 'flexible')  :  [1321]
# ('boundary', 'behavior')  :  [1321]
# ('behavior', 'flexible')  :  [1321]
# ('flexible', 'medium')  :  [1321]
# ('medium', 'also')  :  [1321]
# ('examined', 'practical')  :  [1321]
# ('practical', 'requirements')  :  [1321]
# ('requirements', 'discussed')  :  [1321]
# ('example', 'conclusion')  :  [1321]
# ('conclusion', 'avoid')  :  [1321]
# ('avoid', 'tollmienschlichting')  :  [1321]
# ('tollmienschlichting', 'instability')  :  [1321]
# ('instability', 'wave')  :  [1321]
# ('waves', 'absence')  :  [1321]
# ('absence', 'flow')  :  [1321]
# ('flow', 'coincide')  :  [1321]
# ('coincide', 'tollmienschlichting')  :  [1321]
# ('tollmienschlichting', 'wave')  :  [1321]
# ('velocity', 'wavelength')  :  [1321]
# ('wavelength', 'most')  :  [1321]
# ('most', 'dangerous')  :  [1321]
# ('dangerous', 'tollmienschlichting')  :  [1321]
# ('waves', 'moreover')  :  [1321]
# ('moreover', 'damping')  :  [1321]
# ('damping', 'large')  :  [1321]
# ('enough', 'prevent')  :  [1321]
# ('prevent', 'surface')  :  [1321]
# ('waves', 'developing')  :  [1321]
# ('developing', 'large')  :  [1321]
# ('large', 'tollmienschlichting')  :  [1321]
# ('waves', 'permissable')  :  [1321]
# ('permissable', 'author')  :  [1321]
# ('author', 'states')  :  [1321]
# ('states', 'boundary')  :  [1321]
# ('boundary', 'soft')  :  [1321]
# ('soft', 'light')  :  [1321]
# ('light', 'one')  :  [1321]
# ('one', 'whose')  :  [1321]
# ('whose', 'elastic')  :  [1321]
# ('constants', 'order')  :  [1321]
# ('order', 'dynamic')  :  [1321]
# ('surface', 'small')  :  [1321]
# ('damping', 'avoid')  :  [1321]
# ('tollmienschlichting', 'type')  :  [1321]
# ('type', 'instability')  :  [1321, 1363]
# ('instability', 'large')  :  [1321, 1363]
# ('enough', 'wave')  :  [1321]
# ('speed', 'without')  :  [1321]
# ('without', 'flow')  :  [1321]
# ('flow', 'avoid')  :  [1321]
# ('avoid', 'surface')  :  [1321]
# ('surface', 'wave')  :  [1321]
# ('wave', 'instability')  :  [1321]
# ('instability', 'although')  :  [1321]
# ('although', 'paper')  :  [1321]
# ('paper', 'somewhat')  :  [1321]
# ('somewhat', 'sketchy')  :  [1321]
# ('sketchy', 'places')  :  [1321]
# ('places', 'gives')  :  [1321]
# ('gives', 'comprehensive')  :  [1321]
# ('comprehensive', 'coverage')  :  [1321]
# ('coverage', 'stability')  :  [1321]
# ('flow', 'flexible')  :  [1321]
# ('qualitiative', 'solutions')  :  [1322]
# ('solutions', 'stability')  :  [1322]
# ('stability', 'equation')  :  [1322]
# ('layer', 'contact')  :  [1322]
# ('contact', 'various')  :  [1322]
# ('forms', 'flexible')  :  [1322]
# ('flexible', 'surface')  :  [1322]
# ('appropriate', 'form')  :  [1322]
# ('layer', 'stability')  :  [1322]
# ('developed', 'condition')  :  [1322]
# ('condition', 'fluid')  :  [1322]
# ('fluid', 'contact')  :  [1322]
# ('contact', 'isotropic')  :  [1322]
# ('isotropic', 'homogeneous')  :  [1322]
# ('homogeneous', 'elastic')  :  [1322]
# ('elastic', 'medium')  :  [1322]
# ('medium', 'various')  :  [1322]
# ('obtained', 'certain')  :  [1322]
# ('certain', 'types')  :  [1322, 1363]
# ('types', 'surface')  :  [1322]
# ('surface', 'reveal')  :  [1322]
# ('reveal', 'least')  :  [1322]
# ('least', 'qualitatively')  :  [1322]
# ('qualitatively', 'origin')  :  [1322]
# ('origin', 'characteristics')  :  [1322]
# ('characteristics', 'neutral')  :  [1322]
# ('neutral', 'oscillations')  :  [1322]
# ('oscillations', 'worked')  :  [1322]
# ('worked', 'solutions')  :  [1322]
# ('solutions', 'elastic')  :  [1322]
# ('medium', 'treated')  :  [1322]
# ('treated', 'nondissipative')  :  [1322]
# ('nondissipative', 'interior')  :  [1322]
# ('interior', 'boundary')  :  [1322]
# ('boundary', 'supposed')  :  [1322]
# ('supposed', 'either')  :  [1322]
# ('either', 'fixed')  :  [1322]
# ('fixed', 'free')  :  [1322]
# ('free', 'stress')  :  [1322]
# ('stress', 'exposed')  :  [1322]
# ('exposed', 'fluid')  :  [1322]
# ('treated', 'flatplate')  :  [1322]
# ('flatplate', 'incompressible')  :  [1322]
# ('fluid', 'results')  :  [1322]
# ('show', 'presence')  :  [1322]
# ('presence', 'resiliant')  :  [1322]
# ('resiliant', 'surface')  :  [1322]
# ('surface', 'introduces')  :  [1322]
# ('introduces', 'possibility')  :  [1322]
# ('possibility', 'number')  :  [1322]
# ('number', 'modes')  :  [1322]
# ('oscillation', 'schlichting')  :  [1322]
# ('schlichting', 'waves')  :  [1322]
# ('waves', 'modes')  :  [1322]
# ('modes', 'speeds')  :  [1322]
# ('speeds', 'propagation')  :  [1322]
# ('propagation', 'determined')  :  [1322]
# ('determined', 'largely')  :  [1322]
# ('largely', 'properties')  :  [1322]
# ('properties', 'elastic')  :  [1322]
# ('elastic', 'material')  :  [1322]
# ('material', 'presence')  :  [1322]
# ('presence', 'may')  :  [1322]
# ('may', 'well')  :  [1322]
# ('well', 'effectively')  :  [1322]
# ('effectively', 'matter')  :  [1322]
# ('matter', 'nonviscous')  :  [1322]
# ('flow', 'stability')  :  [1322]
# ('stability', 'dash')  :  [1322]
# ('dash', 'subject')  :  [1322]
# ('subject', 'treated')  :  [1322]
# ('treated', 'tollmienschlichting')  :  [1322]
# ('tollmienschlichting', 'mode')  :  [1322]
# ('mode', 'minimum')  :  [1322]
# ('minimum', 'reynolds')  :  [1322]
# ('increased', 'presence')  :  [1322]
# ('presence', 'surface')  :  [1322]
# ('surface', 'interior')  :  [1322]
# ('boundary', 'free')  :  [1322]
# ('free', 'may')  :  [1322]
# ('may', 'upper')  :  [1322]
# ('limit', 'well')  :  [1322]
# ('well', 'indeed')  :  [1322]
# ('indeed', 'sufficiently')  :  [1322]
# ('thin', 'free')  :  [1322]
# ('free', 'surface')  :  [1322]
# ('surface', 'one')  :  [1322]
# ('one', 'low')  :  [1322]
# ('low', 'rigidity')  :  [1322]
# ('rigidity', 'apparently')  :  [1322]
# ('apparently', 'eliminates')  :  [1322]
# ('eliminates', 'neutral')  :  [1322]
# ('oscillations', 'mode')  :  [1322]
# ('mode', 'altogether')  :  [1322]
# ('altogether', 'expense')  :  [1322]
# ('expense', 'however')  :  [1322]
# ('however', 'introduction')  :  [1322]
# ('introduction', 'mode')  :  [1322]
# ('mode', 'flexural')  :  [1322]
# ('investigation', 'use')  :  [1323]
# ('use', 'auxiliary')  :  [1323]
# ('auxiliary', 'slot')  :  [1323]
# ('slot', 'reestablish')  :  [1323]
# ('reestablish', 'laminar')  :  [1323]
# ('low', 'drag')  :  [1323]
# ('drag', 'aerofoils')  :  [1323]
# ('aerofoils', 'use')  :  [1323]
# ('slot', 'laminarflow')  :  [1323]
# ('laminarflow', 'aerofoil')  :  [1323]
# ('aerofoil', 'investigated')  :  [1323]
# ('investigated', 'check')  :  [1323]
# ('check', 'whether')  :  [1323]
# ('whether', 'laminar')  :  [1323]
# ('flow', 'reestablished')  :  [1323]
# ('reestablished', 'suction')  :  [1323]
# ('suction', 'rear')  :  [1323]
# ('rear', 'region')  :  [1323]
# ('region', 'deposited')  :  [1323]
# ('deposited', 'dirt')  :  [1323]
# ('dirt', 'flies')  :  [1323]
# ('flies', 'etc')  :  [1323]
# ('etc', 'results')  :  [1323]
# ('indicate', 'absence')  :  [1323]
# ('absence', 'unfavourable')  :  [1323]
# ('unfavourable', 'pressure')  :  [1323]
# ('gradients', 'possible')  :  [1323]
# ('possible', 'reestablish')  :  [1323]
# ('layer', 'removing')  :  [1323]
# ('removing', 'little')  :  [1323]
# ('little', 'whole')  :  [1323]
# ('whole', 'turbulent')  :  [1323]
# ('turbulent', 'layer')  :  [1323]
# ('layer', 'reaching')  :  [1323]
# ('reaching', 'slot')  :  [1323]
# ('slot', 'preliminary')  :  [1323]
# ('estimates', 'suggest')  :  [1323, 1324]
# ('suggest', 'efficient')  :  [1323]
# ('efficient', 'ducting')  :  [1323]
# ('ducting', 'possible')  :  [1323]
# ('possible', 'achieve')  :  [1323]
# ('achieve', 'reduction')  :  [1323]
# ('overall', 'effective')  :  [1323]
# ('effective', 'drag')  :  [1323]
# ('coefficient', 'means')  :  [1323]
# ('transition', 'isolated')  :  [1324]
# ('isolated', 'surface')  :  [1324]
# ('surface', 'excrescences')  :  [1324]
# ('excrescences', 'boundary')  :  [1324]
# ('effect', 'isolated')  :  [1324]
# ('excrescences', 'laminar')  :  [1324]
# ('layer', 'producing')  :  [1324]
# ('producing', 'disturbances')  :  [1324]
# ('lead', 'turbulent')  :  [1324]
# ('examined', 'experimentally')  :  [1324]
# ('experimentally', 'several')  :  [1324]
# ('methods', 'photographs')  :  [1324]
# ('patterns', 'visualised')  :  [1324]
# ('visualised', 'smoke')  :  [1324]
# ('smoke', 'chinaclay')  :  [1324]
# ('chinaclay', 'techniques')  :  [1324]
# ('techniques', 'given')  :  [1324]
# ('heights', 'pimple')  :  [1324]
# ('pimple', 'give')  :  [1324]
# ('rise', 'spreading')  :  [1324]
# ('spreading', 'wedges')  :  [1324]
# ('wedges', 'turbulent')  :  [1324, 1325]
# ('flow', 'measured')  :  [1324]
# ('two', 'aerofoils')  :  [1324]
# ('aerofoils', 'several')  :  [1324]
# ('several', 'angles')  :  [1324]
# ('analysed', 'presented')  :  [1324]
# ('form', 'enables')  :  [1324]
# ('enables', 'approximate')  :  [1324]
# ('made', 'protuberances')  :  [1324]
# ('protuberances', 'permissible')  :  [1324]
# ('permissible', 'laminarflow')  :  [1324]
# ('laminarflow', 'surfaces')  :  [1324]
# ('numbers', 'estimates')  :  [1324]
# ('suggest', 'altitude')  :  [1324]
# ('altitude', '30000')  :  [1324]
# ('30000', 'ft')  :  [1324]
# ('ft', 'critical')  :  [1324]
# ('critical', 'pimple')  :  [1324]
# ('pimple', 'height')  :  [1324]
# ('height', '0004')  :  [1324]
# ('0004', 'speed')  :  [1324]
# ('speed', '350')  :  [1324]
# ('350', 'mph')  :  [1324]
# ('mph', 'whilst')  :  [1324]
# ('whilst', '0002')  :  [1324]
# ('0002', 'may')  :  [1324]
# ('may', 'permissible')  :  [1324]
# ('permissible', 'subsonic')  :  [1324]
# ('speeds', 'sealevel')  :  [1324]
# ('sealevel', 'however')  :  [1324]
# ('however', 'tolerances')  :  [1324]
# ('tolerances', 'approximately')  :  [1324]
# ('approximately', 'halved')  :  [1324]
# ('use', 'suction')  :  [1325]
# ('suction', 'perforated')  :  [1325]
# ('perforated', 'strips')  :  [1325]
# ('strips', 'maintaining')  :  [1325]
# ('maintaining', 'laminar')  :  [1325]
# ('transition', 'drag')  :  [1325]
# ('described', 'suction')  :  [1325]
# ('suction', 'applied')  :  [1325]
# ('applied', 'perforated')  :  [1325]
# ('strips', 'alternative')  :  [1325]
# ('alternative', 'porous')  :  [1325]
# ('porous', 'strips')  :  [1325]
# ('strips', 'slots')  :  [1325]
# ('slots', 'order')  :  [1325]
# ('maintain', 'laminar')  :  [1325]
# ('layer', 'test')  :  [1325]
# ('test', 'first')  :  [1325]
# ('first', 'carried')  :  [1325]
# ('carried', 'single')  :  [1325]
# ('single', 'row')  :  [1325]
# ('row', 'perforations')  :  [1325]
# ('perforations', 'cambered')  :  [1325]
# ('cambered', 'plate')  :  [1325]
# ('plate', 'preliminary')  :  [1325]
# ('preliminary', 'main')  :  [1325]
# ('main', 'tests')  :  [1325]
# ('performed', 'strips')  :  [1325]
# ('strips', 'multiple')  :  [1325]
# ('multiple', 'rows')  :  [1325]
# ('rows', 'perforations')  :  [1325]
# ('perforations', 'drilled')  :  [1325]
# ('drilled', 'surface')  :  [1325]
# ('surface', 'lowdragtype')  :  [1325]
# ('lowdragtype', 'aerofoil')  :  [1325]
# ('aerofoil', '13')  :  [1325]
# ('13', 'per')  :  [1325]
# ('cent', 'thick')  :  [1325]
# ('thick', '5ft')  :  [1325]
# ('5ft', 'chord')  :  [1325]
# ('chord', 'wind')  :  [1325]
# ('wind', 'speed')  :  [1325]
# ('speed', '180')  :  [1325]
# ('sec', 'ascertained')  :  [1325]
# ('ascertained', 'suction')  :  [1325]
# ('suction', 'may')  :  [1325]
# ('may', 'safely')  :  [1325]
# ('safely', 'applied')  :  [1325]
# ('applied', 'extend')  :  [1325]
# ('extend', 'laminar')  :  [1325]
# ('provided', 'ratio')  :  [1325]
# ('ratio', 'hole')  :  [1325, 1340]
# ('hole', 'diameter')  :  [1325, 1340]
# ('diameter', 'boundarylayer')  :  [1325]
# ('thickness', 'less')  :  [1325]
# ('less', '2')  :  [1325]
# ('2', 'ratio')  :  [1325]
# ('hole', 'pitch')  :  [1325]
# ('pitch', 'diameter')  :  [1325]
# ('less', '3')  :  [1325]
# ('3', 'least')  :  [1325]
# ('least', 'three')  :  [1325]
# ('three', 'rows')  :  [1325]
# ('rows', 'holes')  :  [1325]
# ('holes', 'strip')  :  [1325]
# ('strip', 'less')  :  [1325]
# ('less', 'three')  :  [1325]
# ('rows', 'criteria')  :  [1325]
# ('criteria', 'much')  :  [1325]
# ('much', 'restrictive')  :  [1325]
# ('restrictive', 'possible')  :  [1325]
# ('possible', 'extend')  :  [1325]
# ('flow', 'suction')  :  [1325]
# ('suction', 'perforations')  :  [1325]
# ('perforations', 'whose')  :  [1325]
# ('whose', 'diameters')  :  [1325]
# ('diameters', 'pitches')  :  [1325]
# ('pitches', 'exceed')  :  [1325]
# ('exceed', 'values')  :  [1325]
# ('values', 'slightly')  :  [1325]
# ('slightly', 'risk')  :  [1325]
# ('risk', 'excessive')  :  [1325]
# ('excessive', 'suction')  :  [1325]
# ('suction', 'quantities')  :  [1325]
# ('quantities', 'produce')  :  [1325]
# ('produce', 'wedges')  :  [1325]
# ('layer', 'originating')  :  [1325]
# ('originating', 'holes')  :  [1325]
# ('holes', 'uniform')  :  [1325]
# ('uniform', 'distribution')  :  [1325]
# ('distribution', 'suction')  :  [1325]
# ('suction', 'holes')  :  [1325]
# ('holes', 'necessary')  :  [1325]
# ('necessary', 'successfully')  :  [1325]
# ('successfully', 'obtained')  :  [1325]
# ('methods', 'use')  :  [1325]
# ('use', 'cells')  :  [1325]
# ('cells', 'throttle')  :  [1325]
# ('throttle', 'holes')  :  [1325]
# ('holes', 'tapered')  :  [1325]
# ('tapered', 'holes')  :  [1325]
# ('holes', 'particular')  :  [1325]
# ('particular', 'tests')  :  [1325]
# ('carried', 'panels')  :  [1325]
# ('panels', 'supplied')  :  [1325]
# ('supplied', 'handley')  :  [1325]
# ('handley', 'page')  :  [1325]
# ('page', 'ltd')  :  [1325]
# ('ltd', 'cells')  :  [1325]
# ('cells', 'tapered')  :  [1325]
# ('holes', 'constructed')  :  [1325]
# ('constructed', 'commercial')  :  [1325]
# ('commercial', 'methods')  :  [1325]
# ('methods', 'suction')  :  [1325]
# ('suction', 'distribution')  :  [1325]
# ('distribution', 'proved')  :  [1325]
# ('satisfactory', 'resistance')  :  [1325]
# ('resistance', 'cellular')  :  [1325]
# ('cellular', 'arrangements')  :  [1325]
# ('arrangements', 'measured')  :  [1325]
# ('measured', 'found')  :  [1325, 1335]
# ('found', 'suction')  :  [1325]
# ('quantities', 'minimum')  :  [1325]
# ('minimum', 'required')  :  [1325]
# ('flow', 'additional')  :  [1325]
# ('additional', 'losses')  :  [1325]
# ('losses', 'total')  :  [1325]
# ('head', 'sucked')  :  [1325]
# ('sucked', 'air')  :  [1325]
# ('air', 'due')  :  [1325]
# ('resistance', 'throttle')  :  [1325]
# ('holes', 'could')  :  [1325]
# ('made', 'small')  :  [1325]
# ('compared', 'loss')  :  [1325]
# ('loss', 'total')  :  [1325]
# ('sucked', 'boundary')  :  [1325]
# ('interaction', 'secondary')  :  [1326]
# ('secondary', 'injectants')  :  [1326]
# ('injectants', 'rocket')  :  [1326]
# ('exhaust', 'thrust')  :  [1326]
# ('control', 'tests')  :  [1326]
# ('conducted', '1300')  :  [1326]
# ('1300', '1500lb')  :  [1326]
# ('1500lb', 'thrust')  :  [1326]
# ('solid', 'rocket')  :  [1326]
# ('motors', 'order')  :  [1326]
# ('investigate', 'sideforce')  :  [1326]
# ('sideforce', 'generation')  :  [1326]
# ('generation', 'mechanisms')  :  [1326]
# ('mechanisms', 'associated')  :  [1326]
# ('associated', 'injection')  :  [1326]
# ('secondary', 'fluid')  :  [1326]
# ('fluid', 'expansion')  :  [1326]
# ('expansion', 'cone')  :  [1326]
# ('cone', 'solid')  :  [1326]
# ('propellant', 'rocket')  :  [1326]
# ('nozzle', 'thrustvector')  :  [1326]
# ('thrustvector', 'control')  :  [1326]
# ('control', 'nozzles')  :  [1326]
# ('nozzles', '15')  :  [1326]
# ('15', 'conicals')  :  [1326]
# ('conicals', 'nominal')  :  [1326]
# ('nominal', 'expansion')  :  [1326]
# ('ratio', 'firings')  :  [1326]
# ('firings', 'conducted')  :  [1326]
# ('conducted', 'zeroflow')  :  [1326]
# ('zeroflow', 'ejectors')  :  [1326]
# ('ejectors', 'freon12')  :  [1326]
# ('freon12', 'water')  :  [1326]
# ('water', 'gascous')  :  [1326]
# ('gascous', 'nitrogen')  :  [1326]
# ('nitrogen', 'used')  :  [1326]
# ('used', 'injectant')  :  [1326]
# ('injectant', 'nozzlewall')  :  [1326]
# ('nozzlewall', 'pressure')  :  [1326]
# ('profiles', 'side')  :  [1326]
# ('side', 'thrust')  :  [1326]
# ('thrust', 'nozzlewall')  :  [1326]
# ('nozzlewall', 'shock')  :  [1326]
# ('shock', 'interface')  :  [1326]
# ('interface', 'recorded')  :  [1326]
# ('recorded', 'general')  :  [1326]
# ('character', 'pressure')  :  [1326]
# ('pressure', 'disturbance')  :  [1326]
# ('disturbance', 'defined')  :  [1326]
# ('defined', 'major')  :  [1326]
# ('portion', 'side')  :  [1326]
# ('generated', 'pressure')  :  [1326]
# ('disturbance', 'downstream')  :  [1326]
# ('downstream', 'injector')  :  [1326]
# ('injector', 'axialthrust')  :  [1326]
# ('axialthrust', 'augmentation')  :  [1326]
# ('augmentation', 'generated')  :  [1326]
# ('generated', 'injectant')  :  [1326]
# ('injectant', 'calculated')  :  [1326]
# ('effects', 'nozzleexpansion')  :  [1326]
# ('nozzleexpansion', 'ratio')  :  [1326]
# ('ratio', 'injector')  :  [1326]
# ('injector', 'location')  :  [1326]
# ('location', 'side')  :  [1326]
# ('force', 'clearly')  :  [1326]
# ('clearly', 'illustrated')  :  [1326]
# ('wave', 'concerning')  :  [1327]
# ('concerning', 'blast')  :  [1327]
# ('waves', 'front')  :  [1327]
# ('front', 'surfaces')  :  [1327]
# ('surfaces', 'plane')  :  [1327]
# ('plane', 'cylindrical')  :  [1327]
# ('shape', 'propagation')  :  [1327]
# ('propagation', 'velocity')  :  [1327]
# ('u', 'distribution')  :  [1327]
# ('distribution', 'hydrodynamical')  :  [1327]
# ('hydrodynamical', 'quantities')  :  [1327]
# ('quantities', 'discussed')  :  [1327]
# ('discussed', 'solutions')  :  [1327]
# ('solutions', 'constructed')  :  [1327]
# ('constructed', 'form')  :  [1327]
# ('series', 'c')  :  [1327]
# ('c', 'u')  :  [1327]
# ('u', 'c')  :  [1327]
# ('c', 'sound')  :  [1327]
# ('undisturbed', 'fluid')  :  [1327]
# ('fluid', 'especially')  :  [1327]
# ('especially', 'r')  :  [1327]
# ('r', 'distance')  :  [1327]
# ('front', 'charge')  :  [1327]
# ('charge', 'represented')  :  [1327]
# ('represented', 'r')  :  [1327]
# ('r', 'characteristic')  :  [1327]
# ('length', 'related')  :  [1327]
# ('related', 'energy')  :  [1327]
# ('energy', 'explosion')  :  [1327]
# ('explosion', 'j')  :  [1327]
# ('j', 'constants')  :  [1327]
# ('constants', 'a012')  :  [1327]
# ('a012', 'correspond')  :  [1327]
# ('correspond', 'plane')  :  [1327]
# ('spherical', 'case')  :  [1327]
# ('case', 'respectively')  :  [1327]
# ('respectively', 'paper')  :  [1327]
# ('approximations', 'a01')  :  [1327]
# ('a01', 'discussed')  :  [1327]
# ('case', 'a2')  :  [1327]
# ('a2', 'discussed')  :  [1327]
# ('discussed', 'g')  :  [1327]
# ('taylor', 'solution')  :  [1327]
# ('obtained', 'numerically')  :  [1327]
# ('numerically', 'case')  :  [1327]
# ('case', 'adiabatic')  :  [1327]
# ('index', 'approximate')  :  [1327]
# ('considered', 'using')  :  [1327]
# ('using', 'solutions')  :  [1327]
# ('found', 'second')  :  [1327]
# ('approximation', 'appear')  :  [1327]
# ('appear', 'part')  :  [1327]
# ('published', 'subsequently')  :  [1327]
# ('production', 'aerodynamic')  :  [1328]
# ('forces', 'heat')  :  [1328]
# ('addition', 'external')  :  [1328]
# ('external', 'surfaces')  :  [1328]
# ('aircraft', 'within')  :  [1328]
# ('framework', 'linearized')  :  [1328]
# ('theory', 'equivalence')  :  [1328]
# ('equivalence', 'fluid')  :  [1328]
# ('fluid', 'mass')  :  [1328]
# ('mass', 'source')  :  [1328]
# ('source', 'heat')  :  [1328]
# ('heat', 'source')  :  [1328]
# ('source', 'streamwise')  :  [1328]
# ('streamwise', 'body')  :  [1328]
# ('developed', 'equivalence')  :  [1328]
# ('source', 'first')  :  [1328]
# ('first', 'noticed')  :  [1328]
# ('noticed', 'hicks')  :  [1328]
# ('hicks', '2')  :  [1328]
# ('2', 'later')  :  [1328]
# ('later', 'chu')  :  [1328]
# ('chu', '3')  :  [1328]
# ('3', 'using')  :  [1328]
# ('equivalence', 'flow')  :  [1328]
# ('produced', 'heat')  :  [1328]
# ('addition', 'magnetohydrodynamical')  :  [1328]
# ('magnetohydrodynamical', 'body')  :  [1328]
# ('computed', 'examples')  :  [1328]
# ('twodimensional', 'flat')  :  [1328]
# ('wing', 'axially')  :  [1328]
# ('symmetric', 'slender')  :  [1328]
# ('body', 'wedgeshaped')  :  [1328]
# ('wedgeshaped', 'afterbody')  :  [1328]
# ('afterbody', 'computed')  :  [1328]
# ('computed', 'subsonic')  :  [1328]
# ('speeds', 'efficiency')  :  [1328]
# ('efficiency', 'lift')  :  [1328]
# ('lift', 'thrust')  :  [1328]
# ('thrust', 'production')  :  [1328]
# ('production', 'surface')  :  [1328]
# ('addition', 'low')  :  [1328]
# ('efficiency', 'compared')  :  [1328]
# ('compared', 'efficiency')  :  [1328]
# ('efficiency', 'conventional')  :  [1328]
# ('conventional', 'turbojetpowered')  :  [1328]
# ('turbojetpowered', 'aircraft')  :  [1328]
# ('aircraft', 'configuration')  :  [1328]
# ('configuration', 'found')  :  [1328]
# ('found', 'efficiency')  :  [1328]
# ('production', 'heat')  :  [1328]
# ('addition', 'twodimensional')  :  [1328]
# ('bodies', 'approximately')  :  [1328]
# ('approximately', 'turbojetpowered')  :  [1328]
# ('turbojetpowered', 'twodimensional')  :  [1328]
# ('body', 'efficiency')  :  [1328]
# ('efficiency', 'somewhat')  :  [1328]
# ('somewhat', 'higher')  :  [1328]
# ('higher', 'low')  :  [1328]
# ('numbers', 'behaves')  :  [1328]
# ('behaves', 'decreasing')  :  [1328]
# ('decreasing', 'constant')  :  [1328]
# ('value', 'increases')  :  [1328]
# ('increases', 'hand')  :  [1328]
# ('hand', 'efficiency')  :  [1328]
# ('efficiency', 'thrust')  :  [1328]
# ('addition', 'increases')  :  [1328]
# ('linearly', 'mach')  :  [1328]
# ('number', 'heat')  :  [1328]
# ('added', 'rear')  :  [1328]
# ('rear', 'surface')  :  [1328]
# ('surface', 'axially')  :  [1328]
# ('symmetric', 'afterbody')  :  [1328]
# ('afterbody', 'parabolic')  :  [1328]
# ('parabolic', 'shape')  :  [1328]
# ('aspects', 'nonstationary')  :  [1329]
# ('nonstationary', 'airfoil')  :  [1329]
# ('theory', 'practical')  :  [1329]
# ('application', 'paper')  :  [1329]
# ('paper', 'consists')  :  [1329]
# ('consists', 'three')  :  [1329]
# ('three', 'notes')  :  [1329]
# ('notes', 'theory')  :  [1329]
# ('airfoils', 'nonuniform')  :  [1329]
# ('motion', 'oscillating')  :  [1329]
# ('airfoil', 'collected')  :  [1329]
# ('collected', 'earlier')  :  [1329]
# ('earlier', 'paper')  :  [1329]
# ('paper', 'presented')  :  [1329]
# ('convenient', 'forms')  :  [1329]
# ('forms', 'practical')  :  [1329]
# ('application', 'rigid')  :  [1329]
# ('rigid', 'airfoil')  :  [1329]
# ('airfoil', 'passing')  :  [1329]
# ('passing', 'verticalgust')  :  [1329]
# ('verticalgust', 'pattern')  :  [1329]
# ('pattern', 'sinusoidal')  :  [1329]
# ('distribution', 'intensity')  :  [1329]
# ('intensity', 'lift')  :  [1329]
# ('lift', 'determined')  :  [1329, 1343]
# ('frequency', 'case')  :  [1329]
# ('case', 'proportional')  :  [1329]
# ('ratio', 'airfoil')  :  [1329]
# ('airfoil', 'chord')  :  [1329]
# ('chord', 'wave')  :  [1329]
# ('length', 'gust')  :  [1329]
# ('gust', 'pattern')  :  [1329]
# ('pattern', 'presented')  :  [1329]
# ('form', 'vector')  :  [1329]
# ('vector', 'diagram')  :  [1329]
# ('diagram', 'shown')  :  [1329]
# ('shown', 'lift')  :  [1329]
# ('lift', 'acts')  :  [1329]
# ('acts', 'quarterchord')  :  [1329]
# ('quarterchord', 'point')  :  [1329]
# ('airfoil', 'times')  :  [1329]
# ('times', 'calculation')  :  [1329]
# ('calculation', 'amplitude')  :  [1329]
# ('amplitude', 'torsional')  :  [1329]
# ('oscillation', 'fan')  :  [1329]
# ('fan', 'blade')  :  [1329]
# ('blade', 'operating')  :  [1329]
# ('operating', 'wake')  :  [1329]
# ('wake', 'set')  :  [1329]
# ('set', 'prerotation')  :  [1329]
# ('prerotation', 'vanes')  :  [1329]
# ('vanes', 'numerical')  :  [1329]
# ('example', 'amplitude')  :  [1329]
# ('amplitude', 'found')  :  [1329]
# ('small', 'even')  :  [1329]
# ('even', 'vanes')  :  [1329]
# ('vanes', 'spaced')  :  [1329]
# ('spaced', 'exciting')  :  [1329]
# ('exciting', 'frequency')  :  [1329]
# ('frequency', 'coincides')  :  [1329]
# ('coincides', 'natural')  :  [1329]
# ('frequency', 'fan')  :  [1329]
# ('transforms', 'theory')  :  [1330]
# ('flows', 'growth')  :  [1330]
# ('lift', 'airfoil')  :  [1330]
# ('airfoil', 'starting')  :  [1330]
# ('starting', 'impulsively')  :  [1330]
# ('impulsively', 'rest')  :  [1330]
# ('given', 'wagner')  :  [1330]
# ('wagner', '1925')  :  [1330]
# ('1925', 'steadystate')  :  [1330]
# ('steadystate', 'lift')  :  [1330]
# ('circulation', 'airfoil')  :  [1330]
# ('oscillating', 'sinusoidally')  :  [1330]
# ('sinusoidally', 'moving')  :  [1330]
# ('given', 'theodorsen')  :  [1330]
# ('theodorsen', 'present')  :  [1330]
# ('based', 'essentially')  :  [1330]
# ('essentially', 'material')  :  [1330]
# ('a', 'report')  :  [1330]
# ('report', '629')  :  [1330]
# ('629', 'author')  :  [1330]
# ('discusses', 'reciprocal')  :  [1330]
# ('transforms', 'existing')  :  [1330]
# ('existing', 'functions')  :  [1330]
# ('functions', 'wagner')  :  [1330]
# ('wagner', 'theodorsen')  :  [1330]
# ('theodorsen', 'kussner')  :  [1330]
# ('kussner', '1936')  :  [1330]
# ('1936', 'already')  :  [1330]
# ('already', 'shown')  :  [1330]
# ('shown', 'wagner')  :  [1330]
# ('wagner', 'function')  :  [1330]
# ('function', 'may')  :  [1330]
# ('may', 'derived')  :  [1330]
# ('derived', 'theodorsen')  :  [1330]
# ('function', 'means')  :  [1330]
# ('means', 'superposition')  :  [1330]
# ('superposition', 'principle')  :  [1330]
# ('principle', 'possible')  :  [1330]
# ('possible', 'utilize')  :  [1330]
# ('utilize', 'fundamental')  :  [1330]
# ('fundamental', 'functions')  :  [1330]
# ('functions', 'treat')  :  [1330]
# ('treat', 'general')  :  [1330]
# ('transient', 'expression')  :  [1330]
# ('expression', 'accurate')  :  [1330]
# ('percent', 'given')  :  [1330]
# ('expression', 'leads')  :  [1330]
# ('good', 'approximate')  :  [1330]
# ('expression', 'theodorsen')  :  [1330]
# ('function', 'terms')  :  [1330]
# ('terms', 'exponential')  :  [1330]
# ('exponential', 'integral')  :  [1330]
# ('integral', 'instead')  :  [1330]
# ('instead', 'hankel')  :  [1330]
# ('hankel', 'functions')  :  [1330]
# ('functions', 'analogy')  :  [1330]
# ('analogy', 'drawn')  :  [1330]
# ('drawn', 'transient')  :  [1330]
# ('transient', 'hydrodynamic')  :  [1330]
# ('hydrodynamic', 'flows')  :  [1330]
# ('flows', 'transient')  :  [1330]
# ('flows', 'kussner')  :  [1330]
# ('1936', 'introduced')  :  [1330]
# ('introduced', 'function')  :  [1330]
# ('function', 'describing')  :  [1330]
# ('describing', 'growth')  :  [1330]
# ('airfoil', 'entering')  :  [1330]
# ('entering', 'sharp')  :  [1330]
# ('sharp', 'edged')  :  [1330]
# ('edged', 'vertical')  :  [1330]
# ('vertical', 'gust')  :  [1330, 1333]
# ('gust', 'region')  :  [1330]
# ('region', 'function')  :  [1330]
# ('function', 'bears')  :  [1330]
# ('bears', 'certain')  :  [1330]
# ('certain', 'relation')  :  [1330]
# ('relation', 'wagner')  :  [1330]
# ('function', 'briefly')  :  [1330]
# ('responses', 'large')  :  [1331]
# ('large', 'sweptwing')  :  [1331]
# ('sweptwing', 'airplane')  :  [1331]
# ('airplane', 'continuous')  :  [1331]
# ('continuous', 'turbulence')  :  [1331]
# ('turbulence', 'flighttest')  :  [1331]
# ('flighttest', 'comparisons')  :  [1331]
# ('comparisons', 'calculated')  :  [1331]
# ('responses', 'symmetrical')  :  [1331]
# ('symmetrical', 'airplane')  :  [1331]
# ('airplane', 'motions')  :  [1331]
# ('motions', 'wing')  :  [1331]
# ('wing', 'deformations')  :  [1331]
# ('deformations', 'wing')  :  [1331]
# ('due', 'gusts')  :  [1331]
# ('gusts', 'shown')  :  [1331]
# ('available', 'flighttest')  :  [1331]
# ('flighttest', 'results')  :  [1331]
# ('responses', 'based')  :  [1331]
# ('based', 'randomprocess')  :  [1331]
# ('randomprocess', 'theory')  :  [1331]
# ('theory', 'five')  :  [1331]
# ('five', 'degrees')  :  [1331]
# ('freedom', 'liftingsurface')  :  [1331]
# ('liftingsurface', 'aerodynamics')  :  [1331]
# ('aerodynamics', 'onedimensional')  :  [1331]
# ('onedimensional', 'vertical')  :  [1331]
# ('vertical', 'turbulence')  :  [1331]
# ('turbulence', 'extent')  :  [1331]
# ('various', 'degrees')  :  [1331]
# ('freedom', 'contribute')  :  [1331]
# ('contribute', 'responses')  :  [1331]
# ('responses', 'examined')  :  [1331]
# ('examined', 'connection')  :  [1331]
# ('connection', 'relative')  :  [1331]
# ('relative', 'effects')  :  [1331]
# ('effects', 'static')  :  [1331]
# ('dynamic', 'aeroelasticity')  :  [1331]
# ('aeroelasticity', 'determined')  :  [1331]
# ('calculated', 'spanwise')  :  [1332, 1334]
# ('distributions', 'influence')  :  [1332]
# ('functions', 'influence')  :  [1332]
# ('coefficients', 'unswept')  :  [1332]
# ('unswept', 'wings')  :  [1332, 1334, 1336, 1339]
# ('flow', 'spanwise')  :  [1332, 1334]
# ('calculated', 'nineteen')  :  [1332]
# ('nineteen', 'unswept')  :  [1332]
# ('ratios', 'variety')  :  [1332, 1334]
# ('variety', 'angleofattack')  :  [1332, 1334]
# ('angleofattack', 'twist')  :  [1332, 1334]
# ('distributions', 'including')  :  [1332, 1334]
# ('including', 'flap')  :  [1332, 1334]
# ('flap', 'aileron')  :  [1332, 1334]
# ('aileron', 'deflections')  :  [1332, 1334]
# ('deflections', 'means')  :  [1332, 1334]
# ('means', 'weissinger')  :  [1332, 1334]
# ('method', 'eight')  :  [1332, 1334]
# ('eight', 'control')  :  [1332, 1334]
# ('points', 'semispan')  :  [1332, 1334]
# ('semispan', 'also')  :  [1332, 1334]
# ('coefficients', 'pertain')  :  [1332, 1334]
# ('pertain', 'certain')  :  [1332, 1334]
# ('certain', 'definite')  :  [1332, 1334]
# ('definite', 'set')  :  [1332, 1334]
# ('set', 'stations')  :  [1332, 1334]
# ('stations', 'along')  :  [1332, 1334]
# ('along', 'span')  :  [1332, 1334]
# ('span', 'several')  :  [1332]
# ('calculating', 'aerodynamic')  :  [1332]
# ('coefficients', 'stations')  :  [1332]
# ('stations', 'stipulated')  :  [1332]
# ('stipulated', 'information')  :  [1332]
# ('herein', 'used')  :  [1332]
# ('analysis', 'untwisted')  :  [1332, 1334]
# ('untwisted', 'wings')  :  [1332, 1334]
# ('wings', 'wings')  :  [1332, 1334]
# ('wings', 'known')  :  [1332, 1334]
# ('known', 'twist')  :  [1332, 1334]
# ('well', 'aeroelastic')  :  [1332]
# ('calculations', 'involving')  :  [1332, 1334]
# ('involving', 'initially')  :  [1332, 1334]
# ('initially', 'unknown')  :  [1332, 1334]
# ('unknown', 'twist')  :  [1332, 1334]
# ('forces', 'wings')  :  [1333]
# ('motion', 'problem')  :  [1333]
# ('acting', 'wings')  :  [1333]
# ('span', 'nonuniform')  :  [1333]
# ('fluid', 'investigated')  :  [1333]
# ('investigated', 'underlying')  :  [1333]
# ('underlying', 'theory')  :  [1333]
# ('outlined', '2')  :  [1333]
# ...
# ('stable', 'scheme')  :  [1390]
# ('scheme', 'computation')  :  [1390]
# ('computation', 'flow')  :  [1390]
# ('examples', 'freestream')  :  [1390]
# ('58', 'presented')  :  [1390]
# ('determined', 'throughout')  :  [1390]
# ('throughout', 'subsonic')  :  [1390]
# ('region', 'particular')  :  [1390]
# ('particular', 'detachment')  :  [1390]
# ('distance', 'location')  :  [1390]
# ('body', 'calculated')  :  [1390]
# ('obtained', 'california')  :  [1390]
# ('wave', 'flow')  :  [1391]
# ('reentry', 'study')  :  [1391]
# ('wave', 'continuumtype')  :  [1391]
# ('continuumtype', 'flow')  :  [1391]
# ('field', 'develop')  :  [1391]
# ('develop', 'nose')  :  [1391]
# ('cooled', 'blunt')  :  [1391]
# ('body', 'reentering')  :  [1391]
# ('regimes', 'encountered')  :  [1391]
# ('encountered', 'low')  :  [1391]
# ('low', 'altitude')  :  [1391]
# ('altitude', 'conditions')  :  [1391]
# ('conditions', 'delineated')  :  [1391]
# ('delineated', 'nature')  :  [1391]
# ('field', 'behavior')  :  [1391]
# ('behavior', 'aerodynamic')  :  [1391]
# ('characteristics', 'discussed')  :  [1391]
# ('shown', 'highly')  :  [1391]
# ('cooled', 'body')  :  [1391]
# ('higher', 'altitude')  :  [1391]
# ('altitude', 'previously')  :  [1391]
# ('previously', 'indicated')  :  [1391]
# ('indicated', 'based')  :  [1391]
# ('based', 'available')  :  [1391]
# ('available', 'evidence')  :  [1391]
# ('evidence', 'suggested')  :  [1391]
# ('suggested', 'kinetic')  :  [1391]
# ('theory', 'solutions')  :  [1391]
# ('solutions', 'essentially')  :  [1391]
# ('essentially', 'modified')  :  [1391]
# ('modified', 'free')  :  [1391]
# ('molecule', 'results')  :  [1391]
# ('results', 'along')  :  [1391]
# ('along', 'navierstokes')  :  [1391]
# ('equations', 'surface')  :  [1391]
# ('surface', 'slip')  :  [1391]
# ('slip', 'serve')  :  [1391]
# ('serve', 'define')  :  [1391]
# ('regimes', 'except')  :  [1391]
# ('except', 'narrow')  :  [1391]
# ('narrow', 'transitional')  :  [1391]
# ('transitional', 'layer')  :  [1391]
# ('regime', 'height')  :  [1391]
# ('one', 'factor')  :  [1391]
# ('factor', '10')  :  [1391]
# ('stream', 'density')  :  [1391]
# ('density', 'change')  :  [1391]
# ('change', 'also')  :  [1391]
# ('also', 'suggested')  :  [1391]
# ('suggested', 'appearance')  :  [1391]
# ('appearance', 'definable')  :  [1391]
# ('definable', 'shock')  :  [1391]
# ('wave', 'occurs')  :  [1391]
# ('occurs', 'rapidly')  :  [1391]
# ('rapidly', 'terms')  :  [1391]
# ('terms', 'density')  :  [1391]
# ('change', 'near')  :  [1391]
# ('near', 'beginning')  :  [1391]
# ('beginning', 'transitional')  :  [1391]
# ('regime', 'location')  :  [1391]
# ('location', 'continuum')  :  [1391]
# ('flow', 'governed')  :  [1391]
# ('governed', 'principally')  :  [1391]
# ('principally', 'body')  :  [1391]
# ('geometry', 'whereas')  :  [1391]
# ('whereas', 'thickness')  :  [1391]
# ('determined', 'local')  :  [1391]
# ('small', 'displacement')  :  [1392]
# ('displacement', 'stability')  :  [1392]
# ('stability', 'vibration')  :  [1392]
# ('vibration', 'problems')  :  [1392]
# ('rectangular', 'panel')  :  [1392]
# ('panel', 'edges')  :  [1392]
# ('edges', 'either')  :  [1392]
# ('either', 'clamped')  :  [1392]
# ('supported', 'report')  :  [1392]
# ('describes', 'energy')  :  [1392]
# ('method', 'exact')  :  [1392]
# ('concerning', 'small')  :  [1392]
# ('displacements', 'stability')  :  [1392]
# ('vibration', 'flat')  :  [1392]
# ('supported', 'influence')  :  [1392]
# ('influence', 'stiffeners')  :  [1392]
# ('stiffeners', 'parallel')  :  [1392]
# ('parallel', 'one')  :  [1392]
# ('pair', 'edges')  :  [1392]
# ('edges', 'situated')  :  [1392]
# ('situated', 'pairs')  :  [1392]
# ('sides', 'panel')  :  [1392]
# ('panel', 'neutral')  :  [1392]
# ('neutral', 'axis')  :  [1392]
# ('axis', 'stiffener')  :  [1392]
# ('stiffener', 'pair')  :  [1392]
# ('pair', 'lies')  :  [1392]
# ('lies', 'middle')  :  [1392]
# ('surface', 'panel')  :  [1392]
# ('panel', 'taken')  :  [1392]
# ('applicable', 'isotropic')  :  [1392]
# ('isotropic', 'panels')  :  [1392]
# ('also', 'aeolotropic')  :  [1392]
# ('aeolotropic', 'panels')  :  [1392]
# ('panels', 'material')  :  [1392]
# ('material', 'panel')  :  [1392]
# ('panel', 'two')  :  [1392]
# ('two', 'directions')  :  [1392]
# ('directions', 'elastic')  :  [1392]
# ('elastic', 'symmetry')  :  [1392]
# ('symmetry', 'parallel')  :  [1392]
# ('parallel', 'edges')  :  [1392]
# ('edges', 'final')  :  [1392]
# ('problems', 'depends')  :  [1392]
# ('depends', 'infinite')  :  [1392]
# ('infinite', 'set')  :  [1392]
# ('displacement', 'problems')  :  [1392]
# ('problems', 'infinite')  :  [1392]
# ('infinite', 'determinantal')  :  [1392]
# ('determinantal', 'equation')  :  [1392]
# ('equation', 'stability')  :  [1392]
# ('problems', 'important')  :  [1392]
# ('feature', 'analysis')  :  [1392]
# ('enables', 'direct')  :  [1392]
# ('direct', 'approach')  :  [1392]
# ('made', 'equations')  :  [1392]
# ('general', 'possible')  :  [1392]
# ('direct', 'solution')  :  [1392]
# ('equations', 'necessary')  :  [1392]
# ('necessary', 'approximate')  :  [1392]
# ('approximate', 'consider')  :  [1392]
# ('consider', 'finite')  :  [1392]
# ('finite', 'set')  :  [1392]
# ('finite', 'determinantal')  :  [1392]
# ('derived', 'important')  :  [1392]
# ('important', 'terms')  :  [1392]
# ('terms', 'analytical')  :  [1392]
# ('expression', 'transverse')  :  [1392]
# ('transverse', 'displacement')  :  [1392]
# ('displacement', 'panel')  :  [1392]
# ('panel', 'physical')  :  [1392]
# ('physical', 'intuition')  :  [1392]
# ('intuition', 'available')  :  [1392]
# ('data', 'serve')  :  [1392]
# ('guide', 'accuracy')  :  [1392]
# ('accuracy', 'final')  :  [1392]
# ('obtained', 'gauged')  :  [1392]
# ('gauged', 'rate')  :  [1392]
# ('convergence', 'increase')  :  [1392]
# ('terms', 'considered')  :  [1392]
# ('first', 'free')  :  [1392]
# ('free', 'vibration')  :  [1392]
# ('vibration', 'square')  :  [1392]
# ('clamped', 'second')  :  [1392]
# ('second', 'buckling')  :  [1392]
# ('shear', 'three')  :  [1392]
# ('three', 'edges')  :  [1392]
# ('clamped', 'one')  :  [1392]
# ('edge', 'simply')  :  [1392]
# ('transfer', 'near')  :  [1393]
# ('point', 'body')  :  [1393]
# ('revolution', 'order')  :  [1393]
# ('moving', 'atmosphere')  :  [1393]
# ('atmosphere', 'knowledge')  :  [1393]
# ('knowledge', 'local')  :  [1393]
# ('required', 'slender')  :  [1393]
# ('slender', 'sharpnosed')  :  [1393]
# ('sharpnosed', 'bodies')  :  [1393]
# ('bodies', 'heattransfer')  :  [1393]
# ('coefficients', 'frequently')  :  [1393]
# ('frequently', 'approximated')  :  [1393]
# ('approximated', 'using')  :  [1393]
# ('using', 'comparable')  :  [1393]
# ('comparable', 'flatplate')  :  [1393]
# ('flatplate', 'values')  :  [1393]
# ('however', 'bluntnosed')  :  [1393]
# ('bodies', 'flatplate')  :  [1393]
# ('flatplate', 'solutions')  :  [1393]
# ('solutions', 'applicable')  :  [1393]
# ('applicable', 'near')  :  [1393]
# ('point', 'since')  :  [1393]
# ('since', 'greatest')  :  [1393]
# ('greatest', 'rate')  :  [1393]
# ('transfer', 'may')  :  [1393]
# ('occur', 'forward')  :  [1393]
# ('point', 'value')  :  [1393]
# ('value', 'investigated')  :  [1393]
# ('investigated', 'note')  :  [1393]
# ('note', 'theoretical')  :  [1393]
# ('revolution', 'assuming')  :  [1393]
# ('assuming', 'laminar')  :  [1393]
# ('incompressible', 'lowspeed')  :  [1393]
# ('flow', 'comparable')  :  [1393]
# ('comparable', 'solution')  :  [1393]
# ('given', 'squire')  :  [1393]
# ('squire', 'case')  :  [1393]
# ('case', 'bluntnosed')  :  [1393]
# ('behind', 'central')  :  [1393]
# ('central', 'portion')  :  [1393]
# ('portion', 'bow')  :  [1393]
# ('wave', 'subsonic')  :  [1393]
# ('subsonic', 'possible')  :  [1393]
# ('possible', 'lowspeed')  :  [1393]
# ('lowspeed', 'solution')  :  [1393]
# ('solution', 'using')  :  [1393]
# ('using', 'freestream')  :  [1393]
# ('behind', 'center')  :  [1393]
# ('center', 'bow')  :  [1393]
# ('wave', 'apply')  :  [1393]
# ('apply', 'near')  :  [1393]
# ('body', 'boundarylayer')  :  [1394]
# ('thickness', 'approaches')  :  [1394]
# ('approaches', 'shocklayer')  :  [1394]
# ('shocklayer', 'thickness')  :  [1394]
# ('thickness', 'shock')  :  [1394]
# ('distance', 'within')  :  [1394]
# ('within', 'region')  :  [1394]
# ('region', 'continuum')  :  [1394]
# ('flow', 'instance')  :  [1394]
# ('instance', 'customary')  :  [1394]
# ('customary', 'boundarylayer')  :  [1394]
# ('approximations', 'longer')  :  [1394]
# ('longer', 'apply')  :  [1394]
# ('apply', 'hoshizaki')  :  [1394]
# ('hoshizaki', 'probstein')  :  [1394]
# ('probstein', 'obtained')  :  [1394]
# ('equations', 'stagnation')  :  [1394]
# ('indicate', 'heattransfer')  :  [1394]
# ('rates', 'substantially')  :  [1394]
# ('substantially', 'higher')  :  [1394]
# ('theory', 'probstein')  :  [1394]
# ('probstein', 'indicated')  :  [1394]
# ('indicated', 'actual')  :  [1394]
# ('rates', 'would')  :  [1394]
# ('would', 'correspondingly')  :  [1394]
# ('correspondingly', 'higher')  :  [1394]
# ('higher', 'predictions')  :  [1394]
# ('predictions', 'fay')  :  [1394]
# ('riddell', 'findings')  :  [1394]
# ('findings', 'particular')  :  [1394]
# ('importance', 'atmospheric')  :  [1394]
# ('entry', 'phase')  :  [1394]
# ('phase', 'recoverable')  :  [1394]
# ('recoverable', 'satellites')  :  [1394]
# ('density', 'stagnation')  :  [1395]
# ('presents', 'absolute')  :  [1395]
# ('absolute', 'heattransfer')  :  [1395]
# ('using', 'resistance')  :  [1395]
# ('resistance', 'thermometer')  :  [1395]
# ('thermometer', 'hemispherecylinder')  :  [1395]
# ('hemispherecylinder', 'mach')  :  [1395]
# ('numbers', '92')  :  [1395]
# ('92', '112')  :  [1395]
# ('112', 'results')  :  [1395]
# ('show', 'vorticityinteraction')  :  [1395]
# ('vorticityinteraction', 'viscouslayer')  :  [1395]
# ('viscouslayer', 'effects')  :  [1395]
# ('effects', 'increase')  :  [1395]
# ('increase', 'heat')  :  [1395]
# ('transfer', 'values')  :  [1395]
# ('predicted', 'boundarylayer')  :  [1395]
# ('correlated', 'using')  :  [1395]
# ('using', 'cheng')  :  [1395]
# ('cheng', 'reynoldsnumberdependent')  :  [1395]
# ('reynoldsnumberdependent', 'parameter')  :  [1395]
# ('parameter', 'investigation')  :  [1395]
# ('covers', 'vorticityinteraction')  :  [1395]
# ('vorticityinteraction', 'incipientmergedlayer')  :  [1395]
# ('incipientmergedlayer', 'regimes')  :  [1395]
# ('regimes', 'freestream')  :  [1395]
# ('freestream', 'unit')  :  [1395]
# ('clamped', 'simplysupported')  :  [1396]
# ('simplysupported', 'infinitely')  :  [1396, 1400]
# ('long', 'plates')  :  [1396, 1400]
# ('plates', 'reinforced')  :  [1396, 1399, 1400]
# ('reinforced', 'transverse')  :  [1396, 1400]
# ('stiffeners', 'paper')  :  [1396]
# ('edges', 'together')  :  [1396]
# ('together', 'extension')  :  [1396]
# ('extension', 'solution')  :  [1396]
# ('obtained', 'stein')  :  [1396]
# ('stein', 'fralich')  :  [1396]
# ('fralich', 'case')  :  [1396]
# ('case', 'edges')  :  [1396]
# ('edges', 'simplysupported')  :  [1396]
# ('simplysupported', 'shown')  :  [1396]
# ('shown', 'consequence')  :  [1396]
# ('consequence', 'increasing')  :  [1396]
# ('increasing', 'edge')  :  [1396]
# ('edge', 'support')  :  [1396]
# ('support', 'simple')  :  [1396]
# ('support', 'one')  :  [1396]
# ('one', 'deflection')  :  [1396]
# ('deflection', 'rotation')  :  [1396]
# ('rotation', 'prevented')  :  [1396]
# ('prevented', 'rigidity')  :  [1396]
# ('rigidity', 'intermediate')  :  [1396]
# ('intermediate', 'transverse')  :  [1396]
# ('transverse', 'stiffener')  :  [1396]
# ('stiffener', 'must')  :  [1396]
# ('must', 'possess')  :  [1396]
# ('possess', 'order')  :  [1396]
# ('order', 'support')  :  [1396]
# ('support', 'plate')  :  [1396]
# ('plate', 'effectively')  :  [1396]
# ('effectively', 'much')  :  [1396]
# ('reduced', 'agreement')  :  [1396]
# ('theoretical', 'relationships')  :  [1396]
# ('relationships', 'existing')  :  [1396]
# ('data', 'good')  :  [1396]
# ('long', 'simply')  :  [1397]
# ('supported', 'plate')  :  [1397]
# ('plate', 'transverse')  :  [1397]
# ('stiffeners', 'theoretical')  :  [1397]
# ('plate', 'identical')  :  [1397]
# ('means', 'lagrangian')  :  [1397]
# ('charts', 'experimental')  :  [1397]
# ('bending', 'forces')  :  [1398]
# ('forces', 'author')  :  [1398]
# ('author', 'first')  :  [1398]
# ('first', 'discusses')  :  [1398]
# ('plane', 'simply')  :  [1398]
# ('plate', 'loaded')  :  [1398]
# ('loaded', 'shearing')  :  [1398]
# ('shearing', 'forces')  :  [1398, 1399]
# ('forces', 'plane')  :  [1398]
# ('plate', 'four')  :  [1398]
# ('edges', 'two')  :  [1398, 1399]
# ('two', 'stiffeners')  :  [1398]
# ('stiffeners', 'attached')  :  [1398]
# ('one', 'third')  :  [1398]
# ('third', 'two')  :  [1398]
# ('two', 'thirds')  :  [1398]
# ('thirds', 'way')  :  [1398]
# ('way', 'along')  :  [1398]
# ('plate', 'critical')  :  [1398]
# ('various', 'stiffener')  :  [1398]
# ('stiffener', 'rigidities')  :  [1398]
# ('rigidities', 'also')  :  [1398]
# ('also', 'rigidity')  :  [1398]
# ('rigidity', 'necessary')  :  [1398]
# ('keep', 'stiffeners')  :  [1398]
# ('stiffeners', 'straight')  :  [1398]
# ('straight', 'plate')  :  [1398]
# ('plate', 'buckles')  :  [1398]
# ('buckles', 'found')  :  [1398]
# ('found', 'stiffener')  :  [1398]
# ('stiffener', 'rigidity')  :  [1398]
# ('rigidity', 'found')  :  [1398]
# ('slightly', 'larger')  :  [1398]
# ('larger', 'necessary')  :  [1398]
# ('necessary', 'plate')  :  [1398]
# ('plate', 'one')  :  [1398]
# ('one', 'stiffener')  :  [1398]
# ('stiffener', 'panel')  :  [1398]
# ('panel', 'dimensions')  :  [1398]
# ('dimensions', 'plate')  :  [1398]
# ('stiffeners', 'second')  :  [1398]
# ('author', 'plane')  :  [1398]
# ('loaded', 'uniformly')  :  [1398]
# ('distributed', 'edge')  :  [1398]
# ('edge', 'shearing')  :  [1398]
# ('linearly', 'distributed')  :  [1398]
# ('distributed', 'tension')  :  [1398]
# ('compression', 'plane')  :  [1398]
# ('plate', 'ends')  :  [1398]
# ('ends', 'end')  :  [1398]
# ('end', 'forces')  :  [1398]
# ('forces', 'vary')  :  [1398]
# ('vary', 'tension')  :  [1398]
# ('tension', 'one')  :  [1398]
# ('one', 'corner')  :  [1398]
# ('corner', 'corner')  :  [1398]
# ('corner', 'resultant')  :  [1398]
# ('resultant', 'bending')  :  [1398]
# ('moment', 'presence')  :  [1398]
# ('presence', 'edge')  :  [1398]
# ('forces', 'found')  :  [1398]
# ('found', 'diminish')  :  [1398]
# ('diminish', 'critical')  :  [1398]
# ('stress', 'case')  :  [1398]
# ('case', 'calculations')  :  [1398]
# ('various', 'magnitudes')  :  [1398]
# ('magnitudes', 'bending')  :  [1398]
# ('bending', 'shearing')  :  [1398]
# ('forces', 'plates')  :  [1398]
# ('various', 'proportions')  :  [1398]
# ('buckling', 'transverse')  :  [1399]
# ('transverse', 'stiffened')  :  [1399]
# ('stiffened', 'plates')  :  [1399]
# ('shear', 'paper')  :  [1399]
# ('analysis', 'buckling')  :  [1399]
# ('reinforced', 'number')  :  [1399]
# ('number', 'transverse')  :  [1399]
# ('stiffeners', 'subjected')  :  [1399]
# ('subjected', 'shearing')  :  [1399]
# ('forces', 'uniformly')  :  [1399]
# ('case', 'plate')  :  [1399]
# ('length', 'ing')  :  [1399]
# ('ing', 'stresses')  :  [1399]
# ('stresses', 'cases')  :  [1399]
# ('cases', 'expressed')  :  [1399]
# ('expressed', 'similar')  :  [1399]
# ('similar', 'forms')  :  [1399]
# ('forms', 'equation')  :  [1399]
# ('equation', '13')  :  [1399]
# ('13', 'k')  :  [1399]
# ('k', 'equation')  :  [1399]
# ('equation', '24')  :  [1399]
# ('24', 'respectively')  :  [1399]
# ('respectively', 'design')  :  [1399]
# ('drawn', 'shown')  :  [1399]
# ('figs', '23')  :  [1399]
# ('23', '5')  :  [1399]
# ('buckling', 'shear')  :  [1400]
# ('stress', 'simplysupported')  :  [1400]
# ('stiffeners', 'report')  :  [1400]
# ('report', 'extension')  :  [1400]
# ('investigations', 'elastic')  :  [1400]
# ('shear', 'flat')  :  [1400]
# ('stiffeners', 'plates')  :  [1400]
# ('plates', 'treated')  :  [1400]
# ('treated', 'infinitely')  :  [1400]
# ('long', 'simplysupported')  :  [1400]
# ('simplysupported', 'along')  :  [1400]
# ('long', 'sides')  :  [1400]
# ('stiffeners', 'spaced')  :  [1400]
# ('spaced', 'regular')  :  [1400]
# ('regular', 'intervals')  :  [1400]
# ('intervals', 'dividing')  :  [1400]
# ('dividing', 'plate')  :  [1400]
# ('plate', 'number')  :  [1400]
# ('number', 'panels')  :  [1400]
# ('panels', 'uniform')  :  [1400]
# ('uniform', 'size')  :  [1400]
# ('effect', 'ob')  :  [1400]
# ('ob', 'bending')  :  [1400]
# ('stiffnesses', 'stiffener')  :  [1400]
# ('stiffener', 'upon')  :  [1400]
# ('stress', 'calculated')  :  [1400]
# ('calculated', 'complete')  :  [1400]
# ('range', 'stiffnesses')  :  [1400]
# ('stiffnesses', 'panels')  :  [1400]
# ('panels', 'ratios')  :  [1400]
# ('ratios', 'width')  :  [1400]
# ('width', 'stiffener')  :  [1400]
# ('stiffener', 'spacing')  :  [1400]
# ('spacing', 'graphical')  :  [1400]
# ('graphical', 'forms')  :  [1400]

# %%
print('No of entries in Bigram Inverted Index: {}'.format(len(bigram_inverted_index)))
# Out:
# No of entries in Bigram Inverted Index: 85114

# %%
# dump bigram inverted index to a pickle file
with open('/content/bigram_inverted_index.pkl', 'wb') as file:
  pickle.dump(bigram_inverted_index, file)

# %% [markdown]
# # **Pre-Processing Input Query**

# %%
# utility method to process the input query, and returns a list of tokens
def preprocess_input(input_str):
  input_str = input_str.lower()
  input_str = re.sub(r'[^\w\s]', '', input_str).split()

  without_stopwords = []
  for word in input_str:
    if word not in stop_words:
      without_stopwords.append(word)

  return without_stopwords

# %%
# utility program to find correct documents for positional indexes
def find_correct_docs(query, index_file):
  result = [index_file[word] for word in query]
  keys_list = [set(dictionary.keys()) for dictionary in result]
  doc_ids = set.intersection(*keys_list)
  postings, final_doc = [], []

  for id in doc_ids:
    temp = [index[id] for index in result]
    postings.append({id: temp})

  for document in postings:
    for key, value in document.items():
      flag, leng = False, len(value)
      for i in value[0]:
        temp = i+1
        for j in range(1, leng):
          if temp in value[j]: flag = True
          else: flag = False
          temp += 1

        if flag: final_doc.append(key)
        continue

  return final_doc

# %%
# method to return document ids
def search_query(query, index, type):
  result = []
  
  if type == 'biword':
    for i in range(len(query)-1):
      temp_tuple = (query[i], query[i+1])
      for key, value in index.items():
        if key == temp_tuple:
          result.append(set(value))
  
  if type == 'positional':
    return find_correct_docs(query, index)

  if len(result)>0:
    return set.intersection(*result)
  else: 
    return {}

# %% [markdown]
# # **(ii) Positional Indexing**

# %%
# method to get the positions of a word in the file, returns a list of indexes
def get_positions(word, content):
  positions = []
  for index, wrd in enumerate(content):
    if wrd == word:
      positions.append(index+1)
      
  return positions

# %%
# creating the positional indexing
positional_index = dict()

for i in range(1, 1401):
  for word in indexed_file_content[i]:
    positions = get_positions(word,indexed_file_content[i])

    if len(positions) > 0:
      if(word in positional_index):
        positional_index[word].update({i: positions})
      else:
        positional_index[word] = {i: positions}

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(dict(list(positional_index.items())[0: 5]))
# Out:
# {   'aerodynamics': {   1: [3],
#                         11: [9],
#                         216: [58],
#                         225: [11],
#                         237: [31],
#                         244: [45],
#                         284: [46],
#                         289: [3],
#                         296: [12],
#                         297: [46],
#                         360: [69],
#                         453: [17],
#                         634: [61, 67],
#                         685: [124],
#                         689: [3],
#                         753: [44, 73],
#                         792: [13],
#                         902: [13],
#                         1206: [59],
#                         1271: [4],
#                         1331: [36],
#                         1347: [21],
#                         1380: [160]},
#     'experimental': {   1: [1, 6],
#                         11: [49],
#                         12: [28],
#                         17: [31],
#                         19: [28],
#                         25: [87],
#                         29: [130],
#                         30: [20],
#                         35: [62],
#                         41: [27],
#                         47: [110],
#                         52: [11],
#                         53: [8],
#                         58: [52],
#                         69: [71],
#                         70: [12],
#                         74: [1],
#                         78: [75],
#                         84: [1, 12],
#                         99: [94, 131],
#                         101: [181],
#                         103: [56],
#                         112: [80],
#                         115: [97],
#                         121: [77],
#                         123: [19, 45],
#                         137: [8],
#                         140: [100],
#                         142: [19],
#                         154: [34],
#                         156: [8],
#                         168: [89],
#                         170: [130],
#                         171: [61],
#                         173: [12, 53],
#                         176: [11],
#                         179: [113, 123],
#                         183: [65],
#                         184: [51],
#                         186: [34, 55],
#                         187: [10],
#                         188: [108],
#                         189: [1],
#                         191: [107],
#                         195: [20, 75, 90],
#                         197: [46, 114],
#                         202: [116],
#                         203: [33],
#                         206: [123, 129],
#                         207: [42, 88],
#                         212: [207],
#                         216: [123],
#                         220: [38],
#                         222: [71],
#                         225: [173],
#                         227: [75],
#                         230: [95],
#                         234: [81, 98, 126, 137],
#                         245: [12],
#                         251: [44],
#                         256: [1, 10],
#                         257: [101],
#                         262: [105],
#                         271: [1, 13],
#                         273: [38],
#                         277: [37],
#                         282: [132],
#                         283: [73],
#                         286: [20],
#                         294: [44],
#                         295: [11],
#                         304: [146],
#                         307: [74],
#                         329: [51, 351],
#                         330: [36],
#                         334: [111, 131],
#                         338: [24],
#                         339: [1],
#                         344: [1, 175],
#                         345: [23],
#                         346: [55, 103],
#                         347: [6],
#                         354: [56],
#                         360: [38],
#                         369: [44],
#                         370: [75],
#                         372: [1, 12],
#                         377: [46],
#                         397: [32],
#                         409: [49],
#                         411: [10, 44],
#                         413: [68, 72],
#                         418: [8],
#                         420: [1],
#                         421: [77],
#                         423: [1],
#                         427: [74],
#                         435: [67],
#                         439: [94],
#                         441: [85],
#                         442: [14, 66],
#                         453: [14],
#                         455: [35, 38],
#                         462: [33],
#                         464: [9],
#                         467: [107],
#                         484: [16, 22, 126],
#                         494: [77, 88],
#                         496: [63],
#                         497: [2],
#                         498: [67],
#                         501: [30],
#                         503: [20],
#                         504: [89],
#                         505: [10],
#                         511: [11],
#                         518: [86],
#                         520: [23, 86],
#                         522: [11, 32, 165],
#                         536: [120],
#                         540: [64],
#                         544: [2, 50],
#                         549: [1],
#                         552: [64, 97],
#                         553: [89],
#                         558: [1],
#                         563: [64],
#                         567: [42],
#                         569: [1],
#                         572: [34, 116, 199, 219],
#                         576: [193],
#                         588: [137],
#                         595: [14],
#                         600: [16],
#                         606: [32],
#                         610: [31],
#                         632: [39],
#                         634: [73],
#                         635: [12],
#                         636: [14],
#                         644: [60],
#                         645: [5],
#                         649: [37],
#                         662: [2],
#                         663: [61, 70],
#                         666: [69, 72],
#                         670: [12],
#                         675: [66],
#                         678: [30],
#                         679: [87],
#                         685: [131, 156, 169],
#                         688: [19, 58, 82],
#                         689: [36, 101],
#                         694: [21],
#                         704: [162, 181],
#                         712: [170],
#                         713: [19],
#                         717: [54],
#                         720: [30],
#                         728: [37],
#                         729: [74],
#                         739: [59],
#                         740: [23],
#                         743: [65],
#                         753: [12],
#                         760: [11, 46, 57],
#                         766: [1, 65],
#                         767: [96, 129, 133],
#                         772: [1, 8],
#                         781: [95, 107],
#                         790: [112],
#                         801: [1, 14],
#                         802: [63],
#                         806: [115],
#                         816: [1],
#                         820: [111],
#                         823: [43, 58],
#                         825: [18],
#                         827: [158],
#                         830: [99],
#                         836: [2, 46, 68, 72],
#                         844: [18],
#                         845: [79],
#                         846: [96],
#                         847: [1],
#                         856: [1, 8, 58],
#                         857: [1, 20],
#                         858: [1, 63],
#                         863: [41, 56],
#                         866: [7, 56],
#                         867: [38],
#                         869: [137],
#                         878: [1],
#                         881: [42],
#                         887: [52],
#                         891: [21, 25],
#                         907: [115],
#                         911: [1],
#                         912: [74],
#                         923: [57],
#                         924: [86],
#                         927: [54],
#                         928: [35, 151, 219],
#                         932: [8, 25],
#                         935: [33, 38],
#                         946: [66],
#                         950: [3, 27, 56],
#                         951: [42],
#                         954: [8, 44],
#                         955: [10],
#                         959: [6],
#                         961: [65],
#                         964: [62],
#                         965: [42],
#                         974: [67],
#                         984: [37, 67],
#                         986: [7, 41, 157],
#                         996: [13],
#                         997: [1, 7, 87],
#                         999: [125],
#                         1006: [44],
#                         1008: [6],
#                         1016: [42],
#                         1019: [45, 85, 106],
#                         1028: [99],
#                         1039: [7, 67, 110],
#                         1040: [7],
#                         1045: [8],
#                         1046: [39],
#                         1049: [43],
#                         1051: [65],
#                         1062: [1, 26],
#                         1066: [143, 191],
#                         1069: [8],
#                         1070: [56],
#                         1074: [2, 50],
#                         1075: [1],
#                         1076: [50],
#                         1078: [42],
#                         1080: [45],
#                         1081: [66],
#                         1082: [145],
#                         1083: [41],
#                         1092: [10],
#                         1097: [1, 7],
#                         1098: [1],
#                         1112: [74],
#                         1118: [25, 37],
#                         1122: [72, 75],
#                         1125: [72],
#                         1127: [92],
#                         1145: [58],
#                         1146: [6],
#                         1151: [22],
#                         1153: [13],
#                         1155: [1],
#                         1156: [1, 13],
#                         1158: [30],
#                         1159: [1],
#                         1160: [31, 62],
#                         1161: [9, 40],
#                         1167: [1],
#                         1171: [43],
#                         1177: [9],
#                         1185: [87],
#                         1186: [51],
#                         1187: [61],
#                         1192: [70],
#                         1195: [156],
#                         1196: [7, 20],
#                         1198: [108],
#                         1199: [108],
#                         1204: [1, 127],
#                         1205: [11],
#                         1209: [6, 76, 144],
#                         1212: [10],
#                         1213: [65, 95],
#                         1214: [26, 32, 48],
#                         1216: [77],
#                         1218: [1],
#                         1220: [8],
#                         1222: [108],
#                         1225: [73, 123, 137],
#                         1227: [9],
#                         1228: [63],
#                         1230: [8],
#                         1231: [44],
#                         1234: [49],
#                         1237: [60],
#                         1261: [138],
#                         1262: [64],
#                         1263: [80],
#                         1264: [8],
#                         1268: [79],
#                         1269: [29, 36],
#                         1277: [118],
#                         1290: [27],
#                         1298: [61],
#                         1302: [74, 83],
#                         1310: [142],
#                         1314: [19, 26],
#                         1337: [7, 82],
#                         1338: [13, 76],
#                         1339: [113],
#                         1341: [46],
#                         1352: [91, 108],
#                         1363: [57, 93],
#                         1364: [1],
#                         1369: [37],
#                         1372: [11],
#                         1374: [63],
#                         1384: [82],
#                         1390: [89],
#                         1392: [128],
#                         1396: [57],
#                         1397: [41]},
#     'investigation': {   1: [2],
#                          8: [59],
#                          9: [12, 176],
#                          19: [1],
#                          29: [131],
#                          30: [2],
#                          44: [84],
#                          45: [1],
#                          50: [1, 11],
#                          56: [43],
#                          73: [1],
#                          74: [22],
#                          78: [8],
#                          79: [8],
#                          80: [15],
#                          82: [2, 98],
#                          84: [2, 13],
#                          89: [1, 10],
#                          90: [7],
#                          126: [1, 6],
#                          128: [10],
#                          129: [1],
#                          135: [26],
#                          165: [138],
#                          170: [131],
#                          173: [13],
#                          174: [1, 17],
#                          176: [12],
#                          179: [10, 85],
#                          184: [5],
#                          187: [1],
#                          188: [10, 77],
#                          189: [2],
#                          197: [17],
#                          198: [1, 10, 34],
#                          202: [50],
#                          205: [14],
#                          207: [9],
#                          212: [32],
#                          213: [5],
#                          214: [11],
#                          216: [5, 39],
#                          222: [11, 69],
#                          225: [85],
#                          228: [10],
#                          243: [1, 18],
#                          245: [13],
#                          246: [13],
#                          251: [45],
#                          252: [1],
#                          260: [19],
#                          265: [37],
#                          280: [29],
#                          294: [1],
#                          312: [15],
#                          339: [25],
#                          342: [97],
#                          365: [25],
#                          372: [2, 13, 55],
#                          374: [1],
#                          390: [19],
#                          423: [2],
#                          427: [35],
#                          433: [17],
#                          434: [12, 66],
#                          436: [9],
#                          442: [15, 67, 70],
#                          462: [69],
#                          463: [5],
#                          474: [6],
#                          497: [3],
#                          505: [11],
#                          513: [35],
#                          522: [12, 40],
#                          527: [27],
#                          549: [26, 39],
#                          552: [98],
#                          566: [1],
#                          567: [82],
#                          569: [2],
#                          571: [12],
#                          634: [18],
#                          635: [13],
#                          636: [15, 113],
#                          638: [14],
#                          643: [1],
#                          651: [36],
#                          655: [19],
#                          662: [3, 45],
#                          665: [22],
#                          673: [1, 13, 33, 75],
#                          689: [1],
#                          692: [1, 15, 55],
#                          693: [1, 15, 59],
#                          694: [22],
#                          695: [17, 153],
#                          696: [18, 116],
#                          700: [31],
#                          709: [20],
#                          710: [8, 111],
#                          711: [1, 17],
#                          712: [13, 80, 166, 175],
#                          713: [20, 42, 57],
#                          739: [62],
#                          747: [13, 30],
#                          757: [1],
#                          759: [2],
#                          766: [2],
#                          772: [9],
#                          780: [14, 35],
#                          782: [50, 83, 102],
#                          796: [1],
#                          797: [12],
#                          801: [15, 71],
#                          804: [3],
#                          808: [1, 16],
#                          809: [1, 19],
#                          811: [1, 10],
#                          812: [1],
#                          815: [1],
#                          816: [2],
#                          826: [91],
#                          836: [3],
#                          841: [22],
#                          844: [19],
#                          855: [29],
#                          858: [2],
#                          859: [14],
#                          875: [3],
#                          887: [53],
#                          892: [17],
#                          905: [48],
#                          907: [38, 77],
#                          927: [1],
#                          932: [9],
#                          933: [71],
#                          946: [2],
#                          952: [31],
#                          953: [20],
#                          959: [8],
#                          960: [1],
#                          970: [31],
#                          971: [13],
#                          972: [17],
#                          986: [42],
#                          992: [11, 144],
#                          993: [21],
#                          994: [1],
#                          996: [14],
#                          997: [28],
#                          1001: [3],
#                          1019: [86],
#                          1039: [8],
#                          1062: [3],
#                          1063: [40],
#                          1065: [2],
#                          1066: [105],
#                          1072: [7],
#                          1074: [3],
#                          1075: [3],
#                          1078: [39],
#                          1083: [1],
#                          1091: [4],
#                          1092: [11],
#                          1094: [1, 19],
#                          1095: [1, 14],
#                          1097: [8],
#                          1098: [2],
#                          1100: [2],
#                          1114: [31],
#                          1116: [29],
#                          1119: [67],
#                          1130: [65],
#                          1144: [150],
#                          1156: [2, 14],
#                          1159: [2],
#                          1161: [10],
#                          1162: [2, 15, 44],
#                          1163: [2, 14, 43],
#                          1164: [17, 73],
#                          1165: [1],
#                          1166: [1, 14],
#                          1205: [12],
#                          1213: [20],
#                          1220: [9],
#                          1225: [69, 74],
#                          1227: [10],
#                          1230: [9],
#                          1231: [45],
#                          1239: [4],
#                          1247: [57],
#                          1271: [72],
#                          1272: [9],
#                          1274: [49],
#                          1309: [85],
#                          1313: [345, 359],
#                          1317: [5],
#                          1319: [51],
#                          1320: [14],
#                          1323: [1],
#                          1337: [9],
#                          1338: [1, 14],
#                          1341: [1, 12],
#                          1343: [43],
#                          1349: [16],
#                          1352: [2, 17],
#                          1353: [1],
#                          1354: [1],
#                          1364: [2, 10, 71],
#                          1367: [2],
#                          1373: [62],
#                          1377: [2],
#                          1381: [130],
#                          1383: [17],
#                          1387: [14],
#                          1395: [41]},
#     'slipstream': {   1: [5, 10, 19, 27, 52],
#                       409: [26],
#                       453: [58, 59, 72, 77, 90, 105],
#                       484: [21, 27, 36, 39, 67, 69, 76],
#                       1064: [2, 34, 37, 73],
#                       1090: [33],
#                       1091: [25],
#                       1094: [15, 53],
#                       1144: [1, 23, 41, 55, 78, 121, 132, 166],
#                       1164: [60],
#                       1165: [21],
#                       1166: [41]},
#     'wing': {   1: [4, 8, 23],
#                 13: [53],
#                 14: [61, 67],
#                 30: [7, 14],
#                 31: [4, 13],
#                 42: [7, 11, 41, 126, 154],
#                 52: [32, 43, 60, 103],
#                 60: [75],
#                 69: [43],
#                 76: [34, 65, 95],
#                 78: [87, 109],
#                 95: [7, 14],
#                 146: [50, 109],
#                 147: [42],
#                 189: [67],
#                 191: [10],
#                 195: [8, 34, 43],
#                 199: [39, 131],
#                 200: [5, 22, 36, 41, 59],
#                 202: [94],
#                 204: [94],
#                 205: [10, 26, 38, 58, 65, 79, 92, 128],
#                 222: [17, 33, 57, 98],
#                 224: [34],
#                 225: [150, 153, 184],
#                 226: [5],
#                 229: [106],
#                 230: [53, 82],
#                 246: [9, 56, 72],
#                 247: [60],
#                 250: [31],
#                 252: [64],
#                 256: [58],
#                 279: [6, 16, 33, 53],
#                 284: [37],
#                 287: [31],
#                 288: [14, 40, 48],
#                 289: [37, 54, 83, 94, 102],
#                 311: [24],
#                 333: [5, 15],
#                 379: [71],
#                 395: [121],
#                 416: [57],
#                 420: [36, 66, 78],
#                 432: [8],
#                 433: [28, 38, 54, 108, 121, 179, 195, 200, 205, 220, 227],
#                 434: [2, 24, 36],
#                 442: [53],
#                 453: [62, 65, 69, 119],
#                 464: [76, 92],
#                 486: [72],
#                 497: [8, 21, 57],
#                 512: [33],
#                 520: [65],
#                 547: [25],
#                 561: [8, 77, 88],
#                 599: [110],
#                 600: [65],
#                 601: [14, 55, 126],
#                 632: [43],
#                 633: [50],
#                 636: [47, 132],
#                 638: [9, 35, 49, 61, 65, 124],
#                 643: [12, 18, 64],
#                 671: [6, 16],
#                 673: [7, 30, 49, 57, 70, 96, 102, 111, 117, 192, 218],
#                 674: [32],
#                 675: [56, 133],
#                 676: [29],
#                 677: [92, 122],
#                 680: [6, 15, 28],
#                 681: [5, 10, 27],
#                 682: [26],
#                 683: [10, 25, 54, 69, 107, 125],
#                 692: [25, 88],
#                 693: [30, 92, 99],
#                 694: [42, 54, 82, 95],
#                 695: [33, 45, 164, 176, 202],
#                 696: [5, 11, 32, 39, 68, 90, 125, 140, 145, 161, 166],
#                 698: [3, 20, 28, 33, 78],
#                 699: [17, 52],
#                 703: [34, 41],
#                 705: [31],
#                 709: [70, 99],
#                 711: [59],
#                 712: [37, 39, 77, 137, 139],
#                 714: [20],
#                 747: [37, 69],
#                 748: [29, 63],
#                 749: [6, 19, 57],
#                 752: [3, 52],
#                 755: [15, 53],
#                 757: [22, 117, 169],
#                 768: [7, 33],
#                 779: [7],
#                 781: [21, 85],
#                 783: [7, 19, 54],
#                 791: [45],
#                 793: [5, 14, 20, 85],
#                 794: [4, 15, 44, 63, 112, 123, 134, 158],
#                 795: [28],
#                 796: [68],
#                 797: [8, 25, 65, 137, 147, 158, 184],
#                 803: [29, 37, 63],
#                 808: [54],
#                 811: [116, 118],
#                 860: [6, 15, 20],
#                 877: [7, 14, 24, 27],
#                 883: [14],
#                 895: [6, 16],
#                 901: [16],
#                 902: [53, 64, 80, 92],
#                 916: [20, 61],
#                 917: [8, 21, 123],
#                 918: [6, 15],
#                 919: [13, 26],
#                 920: [4, 16],
#                 921: [75, 85, 101],
#                 923: [35, 41],
#                 924: [45, 66, 105],
#                 929: [23, 86],
#                 970: [5, 10, 22, 27, 83],
#                 1062: [21, 38],
#                 1064: [5, 21, 27],
#                 1074: [23],
#                 1075: [14, 24, 66],
#                 1089: [60, 64],
#                 1091: [18, 29, 38, 58],
#                 1092: [22, 33, 62, 86, 137, 162],
#                 1094: [8, 26, 49, 72],
#                 1095: [16, 47, 63, 88],
#                 1111: [26],
#                 1115: [23, 75],
#                 1128: [60],
#                 1144: [91],
#                 1162: [35, 62],
#                 1163: [33, 70],
#                 1164: [15, 30, 34],
#                 1168: [46],
#                 1169: [43, 58],
#                 1170: [64],
#                 1186: [18, 49],
#                 1188: [90, 93],
#                 1207: [79, 101],
#                 1208: [6],
#                 1218: [43, 158],
#                 1229: [61, 101, 132],
#                 1233: [19],
#                 1239: [3, 17, 19, 46, 57, 81, 112, 158, 174, 186],
#                 1243: [16, 18],
#                 1246: [23, 32, 81, 126, 141],
#                 1266: [2, 15],
#                 1276: [7],
#                 1277: [144, 147],
#                 1280: [20, 32, 133, 139],
#                 1289: [15, 41, 50, 111],
#                 1290: [9, 37, 100],
#                 1328: [53],
#                 1331: [15, 17],
#                 1333: [74],
#                 1336: [99],
#                 1337: [39],
#                 1338: [12],
#                 1340: [7, 17, 21, 24, 47, 59],
#                 1341: [2, 9, 16, 101, 103],
#                 1342: [28, 77, 93, 117],
#                 1343: [55, 94, 126],
#                 1362: [28, 57],
#                 1380: [139]}}

# %%
print('No of entries in Positional Index: {}'.format(len(positional_index)))
# Out:
# No of entries in Positional Index: 8967

# %%
# dump positional index to a pickle file
with open('/content/positional_index.pkl', 'wb') as file:
  pickle.dump(positional_index, file)

# %% [markdown]
# # **Adding the main function**

# %%
if __name__ == '__main__':
  BIGRAM_MODEL_PATH = '/content/bigram_inverted_index.pkl'
  POSITIONAL_MODEL_PATH = '/content/positional_index.pkl'

  with open(BIGRAM_MODEL_PATH, 'rb') as file: bigram_index = pickle.load(file)
  with open(POSITIONAL_MODEL_PATH, 'rb') as file: positional_index = pickle.load(file)

  n = int(input("Enter Number of Queries you want to execute: "))
  queries = []
  for i in range(n):
    query = input("Enter Query {}: ".format(i+1))
    queries.append(query)

  for index, query in enumerate(queries):
    processed_words = preprocess_input(query)
    result_biword = search_query(processed_words, bigram_index, "biword")
    result_positional = search_query(processed_words, positional_index, "positional")

    result_biword = (sorted(set(result_biword)))
    file_names_biword = ["cranfield00"+str(i) for i in result_biword]
    print(f"\nNumber of documents retrieved for query {index+1} using bigram inverted index: {len(file_names_biword)}")
    print(f"Names of documents retrieved for query {index+1} using bigram inverted index: {file_names_biword}")

    result_positional = (sorted(set(result_positional)))
    file_names_positional = ["cranfield00"+str(i) for i in result_positional]
    print(f"\nNumber of documents retrieved for query {index+1} using positional index: {len(file_names_positional)}")
    print(f"Names of documents retrieved for query {index+1} using positional index: {file_names_positional}")
# Out:
# Enter Number of Queries you want to execute: 3
# Enter Query 1: jet Propulsion
# Enter Query 2: slipstream Experimental Investigation
# Enter Query 3: Transient heAt conducTion
#
# Number of documents retrieved for query 1 using bigram inverted index: 6
# Names of documents retrieved for query 1 using bigram inverted index: ['cranfield007 cranfield0040 cranfield00182 cranfield001151 cranfield001211 cranfield001212']
#
# Number of documents retrieved for query 1 using positional index: 6
# Names of documents retrieved for query 1 using positional index: ['cranfield007 cranfield0040 cranfield00182 cranfield001151 cranfield001211 cranfield001212']
#
# Number of documents retrieved for query 2 using bigram inverted index: 1
# Names of documents retrieved for query 2 using bigram inverted index: ['cranfield001']
#
# Number of documents retrieved for query 2 using positional index: 0
# Names of documents retrieved for query 2 using positional index: ['']
#
# Number of documents retrieved for query 3 using bigram inverted index: 2
# Names of documents retrieved for query 3 using bigram inverted index: ['cranfield005 cranfield00978']
#
# Number of documents retrieved for query 3 using positional index: 2
# Names of documents retrieved for query 3 using positional index: ['cranfield005 cranfield00978']

# %% [markdown]
# # **(iii) Compare and comment on your results using (i) and (ii)**

# %% [markdown]
# For the query 1: **"slipstream experimental Investigation"**\
# Bigram Index returns 1 file, but positional index returns 0 file. This is because bigram indexes gives ***FALSE POSITIVE*** results which is not an issue in positional indexing. In the document **"cranfield001"**, (slipstream experimental), and (experimental Investigation) exists but not in the correct order or sequence so it gives this file as output.This is the limitation of bigram indexing and hence we use positional indexing.
